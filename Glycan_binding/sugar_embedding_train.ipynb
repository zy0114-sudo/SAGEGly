# %% [markdown]
# #训练集的embedding

# %%
import os  # #
#from data_processing.Extract_Interface import Extract_Interface
import numpy as np
np.set_printoptions(suppress=True)  # 取消科学计数法输出
np.set_printoptions(threshold = np.inf)
import math
import operator
from functools import reduce
from scipy.spatial import distance_matrix
ee=math.e
import torch

# %%
def read_frequency_table(file_path):
    """
    读取频率分布表
    :param file_path: 频率分布表文件路径
    :return: 频率矩阵
    """
    frequency_matrix = []
    try:
        with open(file_path, 'r') as file:
            lines = file.readlines()
            # 跳过表头
            for line in lines[1:]:
                # 跳过第一列的氨基酸名称
                row = [int(val) for val in line.strip().split('\t')[1:]]
                frequency_matrix.append(row)
    except FileNotFoundError:
        print(f"未找到频率分布表文件: {file_path}")
    return np.array(frequency_matrix)

# %%
MaxASA = {  
        "ALA": 129.0,  # Alanine  
        "ARG": 274.0,  # Arginine  
        "ASN": 195.0,  # Asparagine  
        "ASP": 193.0,  # Aspartate (Aspartic acid)  
        "CYS": 167.0,  # Cysteine  
        "GLU": 223.0,  # Glutamate (Glutamic acid)  
        "GLN": 225.0,  # Glutamine  
        "GLY": 104.0,  # Glycine  
        "HIS": 224.0,  # Histidine  
        "ILE": 197.0,  # Isoleucine  
        "LEU": 201.0,  # Leucine  
        "LYS": 236.0,  # Lysine  
        "MET": 224.0,  # Methionine  
        "PHE": 240.0,  # Phenylalanine  
        "PRO": 159.0,  # Proline  
        "SER": 155.0,  # Serine  
        "THR": 172.0,  # Threonine  
        "TRP": 285.0,  # Tryptophan  
        "TYR": 263.0,  # Tyrosine  
        "VAL": 174.0   # Valine  
        }  

amino_acid_order = [
    'CYS', 'SER', 'THR', 'PRO', 'ALA', 'GLY', 'ASN', 'ASP', 'GLU', 'GLN',
    'HIS', 'ARG', 'LYS', 'MET', 'ILE', 'LEU', 'VAL', 'PHE', 'TYR', 'TRP']

# %%
def one_of_k_encoding(x, allowable_set):
            if x not in allowable_set:
                # print(x)
                raise Exception('input {0} not in allowable set{1}:'.format(x, allowable_set))
            return list(map(lambda s: x == s, allowable_set))
    
def residue_features(residue):
            res_property1 = [1 if residue in pro_res_aliphatic_table else 0, 
                                1 if residue in pro_res_aromatic_table else 0,
                                1 if residue in pro_res_polar_neutral_table else 0,
                                1 if residue in pro_res_acidic_charged_table else 0,
                                1 if residue in pro_res_basic_charged_table else 0]
            res_property2 = [res_weight_table[residue], res_pka_table[residue], res_pkb_table[residue], res_pl_table[residue]]
            #print(np.array(res_property1 + res_property2+res_property3).shape)
            #return np.array(res_property1 + res_property2+res_property3)
            features=(res_property1 + res_property2)
            return features

# %%
def read_frequency_table(file_path):
    """
    读取频率分布表
    :param file_path: 频率分布表文件路径
    :return: 频率矩阵
    """
    frequency_matrix = []
    try:
        with open(file_path, 'r') as file:
            lines = file.readlines()
            # 跳过表头
            for line in lines[1:]:
                # 跳过第一列的氨基酸名称
                row = [int(val) for val in line.strip().split('\t')[1:]]
                frequency_matrix.append(row)
    except FileNotFoundError:
        print(f"未找到频率分布表文件: {file_path}")
    return np.array(frequency_matrix)

def calculate_exposed_residues(sasa_file_path, pdb_file_path, threshold=0.5):
    """
    计算给定 SASA 文件中暴露的 CA 原子的索引
    :param sasa_file_path: SASA 文件路径
    :param pdb_file_path: PDB 文件路径
    :param threshold: RSA 阈值，默认为 0.1
    :return: 暴露 CA 原子的索引列表
    """
    sasa_data = []
    try:
        with open(sasa_file_path, 'r') as rec_file:
            for line in rec_file:
                if line.startswith('SEQ'):
                    try:
                        residue_name = line[12:15].strip()
                        sasa_value = float(line[19:26].strip())
                        sasa_data.append((residue_name, sasa_value))
                    except (ValueError, IndexError):
                        print(f"解析行 '{line.strip()}' 时出错，跳过该行。")
    except FileNotFoundError:
        print(f"未找到文件: {sasa_file_path}")

    exposed_indices = []
    ca_index = 0
    with open(pdb_file_path, 'r') as pdb_file:
        for line in pdb_file:
            if line[:4] == 'ATOM' and line[12:16].strip() == 'C':
                if ca_index < len(sasa_data):
                    exposed_indices.append(ca_index)
                ca_index += 1
    print(ca_index)
    return exposed_indices, sasa_data


def get_c_coordinates(pdb_file):
    """
    从 PDB 文件中获取所有 CA 原子的坐标
    :param pdb_file: PDB 文件路径
    :return: CA 原子坐标的 numpy 数组
    """
    ca_accord = []
    with open(pdb_file, 'r') as file:
        lines = file.readlines()
        for line in lines:
            if line[:4] == 'ATOM' and line[12:16].strip() == 'C':
                x = float(line[31:38])
                y = float(line[39:46])
                z = float(line[47:54])
                ca_accord.append([x, y, z])
    return np.array(ca_accord)

# %%
def  get_residue(sasa_file):
    residues=[]
    
    index=0
    with open(sasa_file, 'r') as rec_file:
            for line in rec_file:
                if line.startswith('SEQ'):
                    residue_name = line[12:15].strip()
                    resid=line[6:11].strip()
                    chain_id=line[4]
                    residues.append((chain_id,resid,residue_name))
    return residues

def get_index(gly_residue,A_residue):
    index=[]
    for i,value1 in enumerate(A_residue):
        for j,value2 in enumerate(gly_residue):
            if value2==value1:
                index.append(i)
    return index

# %%
path='/Glycan_binding/train'
save_npz_path='/Glycan_binding/train_npz'

# %%
interface_rec_list = [f for f in os.listdir(path) ]
interface_rec_list.sort()

# %%
for num2,numm in enumerate(interface_rec_list):
    
    #if numm !='6PX5_1_X_B':
    #   continue
    print(numm)
    B_chain=numm[-3]
    A_chain=numm[-1]
    all_path_A=f'/Glycan_binding/train/{numm}/A/all/{numm}.pdb'
    all_path_A_sasa=f'/Glycan_binding/train/{numm}/A/all/sasa/{numm}.pdb'
    glycan_path_A=f'/Glycan_binding/train/{numm}/A/glycan/{numm}.pdb'
    glycan_path_A_sasa=f'/Glycan_binding/train/{numm}/A/glycan/sasa/{numm}.pdb'
    ppi_path_A=f'/Glycan_binding/train/{numm}/A/ppi/{numm}.pdb'
    ppi_path_A_sasa=f'/Glycan_binding/train/{numm}/A/ppi/sasa/{numm}.pdb'

    #pt_A_name=f'{numm}_{A_chain}.pt'
    #A_ppt=f'/glycan_binding/{numm}/A/all_esm/{pt_A_name}'
    #pt_B_name=f'{numm}_{B_chain}.pt'
    #B_ppt=f'/glycan_binding/{numm}/B/all_esm/{pt_B_name}'
    
    all_path_B=f'/Glycan_binding/train/{numm}/B/all/{numm}.pdb'
    all_path_B_sasa=f'/Glycan_binding/train/{numm}/B/all/sasa/{numm}.pdb'
    glycan_path_B=f'/Glycan_binding/train/{numm}/B/glycan/{numm}.pdb'
    glycan_path_B_sasa=f'/Glycan_binding/train/{numm}/B/glycan/sasa/{numm}.pdb'
    ppi_path_B=f'/Glycan_binding/train/{numm}/B/ppi/{numm}.pdb'
    ppi_path_B_sasa=f'/Glycan_binding/train/{numm}/B/ppi/sasa/{numm}.pdb'
    esm_feature=torch.load(f'/PPI/train/hebin_esm/{numm}_{A_chain}.pt')
    ems_33 = esm_feature['representations'][33] 
    #print(np.shape(ems_33))

    
    
    ##############esm_ppi特征提取-A######################
    all_resid_A=[]
    ppi_resid_A=[]
    with open(all_path_A_sasa,'r') as rec_file:
        line1 = rec_file.readlines() 
    for i in line1:
            if i[0:3] =='SEQ':
                i=i.strip()
                bb=i[12:15]
                dd=i[6:11].strip()
                cc=float(i[19:26])
                all_resid_A.append(dd) 
                
    with open(ppi_path_A_sasa,'r') as rec_file:          
        line2 = rec_file.readlines() 
    for i in line2:
            if i[0:3] =='SEQ':
                i=i.strip()
                bb=i[12:15]
                dd=i[6:11].strip()
                cc=float(i[19:26])
                ppi_resid_A.append(dd)  
    yy_A=[]
    for i,value in enumerate(all_resid_A):
        if value in ppi_resid_A:
            yy_A.append(i)
    
    
    ##############esm_ppi特征提取-B######################
    all_resid_B=[]
    ppi_resid_B=[]
    with open(all_path_B_sasa,'r') as rec_file:
        line1 = rec_file.readlines() 
    for i in line1:
            if i[0:3] =='SEQ':
                i=i.strip()
                bb=i[12:15]
                dd=i[6:11].strip()
                cc=float(i[19:26])
                all_resid_B.append(dd) 
                
    with open(ppi_path_B_sasa,'r') as rec_file:       
        line2 = rec_file.readlines() 
    for i in line2:
            if i[0:3] =='SEQ':
                i=i.strip()
                bb=i[12:15]
                dd=i[6:11].strip()
                cc=float(i[19:26])
                ppi_resid_B.append(dd)  
    yy_B=[]
    for i,value in enumerate(all_resid_B):
        if value in ppi_resid_B:
            yy_B.append(i)  
            
    #############ppi的esm拼接#####################
    
    A_len=len(all_resid_A)
    A_ems=ems_33[0:A_len]
    #print('A_ems...',np.shape(A_ems))
    B_ems=ems_33[A_len:]
    #print('B_ems...',np.shape(B_ems))
    A_ems_new=A_ems[yy_A]
    #print('A_ems_new',np.shape(A_ems_new))
    B_ems_new=B_ems[yy_B]
    #print('B_ems_new',np.shape(B_ems_new))#
    esm_all=torch.cat((A_ems_new,B_ems_new),dim=0)
    
    
        ####################################归一化#############################################
    def dic_normalize(dic): #计算方法为：该值-最小值/最大值-最小值  归一化 
            #print(dic)
            max_value = dic[max(dic, key=dic.get)]
            min_value = dic[min(dic, key=dic.get)]
            #print(max_value)
            #print(min_value)
            interval = float(max_value) - float(min_value)
            #print('interval',interval)
            for key in dic.keys():
                dic[key] = round((dic[key] - min_value) / interval,4)
            dic['X'] = (max_value + min_value) / 2.0  #在字典中添加X 记录为最大值和最小值的平均值
            return dic
    # 归一化
    def normalize_pssm(value):        #position specific scoring matrix 位置特异性评分矩阵
            pssm=1/(1+ee**-value)
            pssm=round(pssm,4)
            return pssm
        
    pro_res_table = ['ALA ', 'CYS ', 'ASP ', 'GLU ', 'PHE ', 'GLY ', 'HIS ', 'ILE ', 'LYS ', 'LEU ', 'MET ', 'ASN ', 'PRO ', 'GLN ', 
                         'ARG ', 'SER ', 
                         'THR ', 'VAL ', 'TRP ', 'TYR ']
        #Whether the residue is aliphatic(脂肪族氨基酸)
    pro_res_aliphatic_table = ['ALA ', 'ILE ', 'LEU ', 'MET ', 'VAL ']
        #Whether the residue is aromatic（芳香性氨基酸）
    pro_res_aromatic_table = ['PHE ', 'TRP ', 'TYR ']
        #Whether the residue is polar neutral（中性氨基酸）
    pro_res_polar_neutral_table = ['CYS ', 'ASN ', 'GLN ', 'SER ', 'THR ']
        #Whether the residue is acidic charged（酸性氨基酸）
    pro_res_acidic_charged_table = ['ASP ', 'GLU ']
        #Whether the residue is basic charged（碱性氨基酸）
    pro_res_basic_charged_table = ['HIS ', 'LYS ', 'ARG ']
        #Residue weight（分子量）
    res_weight_table = {'ALA ': 71.08, 'CYS ': 103.15, 'ASP ': 115.09, 'GLU ': 129.12, 'PHE ': 147.18, 'GLY ': 57.05, 'HIS ': 137.14,
                                        'ILE ': 113.16, 'LYS ': 128.18, 'LEU ': 113.16, 'MET ': 131.20, 'ASN ': 114.11, 'PRO ': 97.12, 'GLN ': 128.13,
                                        'ARG ': 156.19, 'SER ': 87.08, 'THR ': 101.11, 'VAL ': 99.13, 'TRP ': 186.22, 'TYR ': 163.18}
        #The negative of the logarithm of the dissociation constant for the –COOH group（羧基的解离常数的负对数pK1）
    res_pka_table = {'ALA ': 2.34, 'CYS ': 1.96, 'ASP ': 1.88, 'GLU ': 2.19, 'PHE ': 1.83, 'GLY ': 2.34, 'HIS ': 1.82, 'ILE ': 2.36,
                                     'LYS ': 2.18, 'LEU ': 2.36, 'MET ': 2.28, 'ASN ': 2.02, 'PRO ': 1.99, 'GLN ': 2.17, 'ARG ': 2.17, 'SER ': 2.21,
                                     'THR ': 2.09, 'VAL ': 2.32, 'TRP ': 2.83, 'TYR ': 2.32}
        #The negative of the logarithm of the dissociation constant for the –NH3 group（氨基的解离常数的负对数pK2）
    res_pkb_table = {'ALA ': 9.69, 'CYS ': 10.28, 'ASP ': 9.60, 'GLU ': 9.67, 'PHE ': 9.13, 'GLY ': 9.60, 'HIS ': 9.17,
                 'ILE ': 9.60, 'LYS ': 8.95, 'LEU ': 9.60, 'MET ': 9.21, 'ASN ': 8.80, 'PRO ': 10.60, 'GLN ': 9.13,
                 'ARG ': 9.04, 'SER ': 9.15, 'THR ': 9.10, 'VAL ': 9.62, 'TRP ': 9.39, 'TYR ': 9.62}
        #The pH at the isoelectric point（等电点）
    res_pl_table = {'ALA ': 6.00, 'CYS ': 5.07, 'ASP ': 2.77, 'GLU ': 3.22, 'PHE ': 5.48, 'GLY ': 5.97, 'HIS ': 7.59,
                        'ILE ': 6.02, 'LYS ': 9.74, 'LEU ': 5.98, 'MET ': 5.74, 'ASN ': 5.41, 'PRO ': 6.30, 'GLN ': 5.65,
                        'ARG ': 10.76, 'SER ': 5.68, 'THR ': 5.60, 'VAL ': 5.96, 'TRP ': 5.89, 'TYR ': 5.96}
        #Hydrophobicity of residue (pH=2)
    res_hydrophobic_ph2_table = {'ALA ': 47, 'CYS ': 52, 'ASP ': -18, 'GLU ': 8, 'PHE ': 92, 'GLY ': 0, 'HIS ': -42, 'ILE ': 100,
                                     'LYS ': -37, 'LEU ': 100, 'MET ': 74, 'ASN ': -41, 'PRO ': -46, 'GLN ': -18, 'ARG ': -26, 'SER ': -7,
                                     'THR ': 13, 'VAL ': 79, 'TRP ': 84, 'TYR ': 49}
        #Hydrophobicity of residue (pH=7)
    res_hydrophobic_ph7_table = {'ALA ': 41, 'CYS ': 49, 'ASP ': -55, 'GLU ': -31, 'PHE ': 100, 'GLY ': 0, 'HIS ': 8, 'ILE ': 99,
                                 'LYS ': -23, 'LEU ': 97, 'MET ': 74, 'ASN ': -28, 'PRO ': -46, 'GLN ': -10, 'ARG ': -14, 'SER ': -5,
                                 'THR ': 13, 'VAL ': 76, 'TRP ': 97, 'TYR ': 63}
    res_weight_table = dic_normalize(res_weight_table)
    res_pka_table = dic_normalize(res_pka_table)
    res_pkb_table =dic_normalize(res_pkb_table)
    res_pl_table =dic_normalize(res_pl_table)
    res_hydrophobic_ph2_table =dic_normalize(res_hydrophobic_ph2_table)
    res_hydrophobic_ph7_table = dic_normalize(res_hydrophobic_ph7_table)
    
    
    
    #######################节点特征计算A################3   ppi拼接
    value1=[]
    res_list=[]
    value2=[]
    value3=[]
    res_list2=[]
    with open(all_path_A_sasa,'r') as rec_file:
            line = rec_file.readlines()
            for x in line:
                if x[0:3]=='SEQ':
                    x=x.strip()
                    resid=x[12:16]   #氨基酸的名称
                    sasa_value=x[19:26]  #溶剂可及表面积
                    dd=x[6:11].strip()   #氨基酸号
                    #print(dd,resid,sasa_value)
                    value1.append(sasa_value)
                    res_list.append(resid)
                    if dd in ppi_resid_A:
                        value3.append(sasa_value)
                        res_list2.append(resid)  #pos
    maxnum=float(max(value1))
    minnum=float(min(value1))
    internal_value=maxnum-minnum
    for x1 in value3:   #pos
        x1=float(x1)
        final_value=round((x1-minnum)/internal_value,4) 
        value2.append(final_value)  #pos
    
    rec_fea_A=[]
    if len(value2)==len(res_list2): 
        for m in range(len(value2)):
            sasa=[value2[m]] #sasa为归一化后的值
            pro_seq=[res_list2[m]]  #氨基酸名称
            resid=res_list2[m]
            pro_hot=np.zeros((1,len(pro_res_table)))  
            for i in range(len(pro_seq)):  #i=1
                pro_hot[i,] = one_of_k_encoding(pro_seq[i], pro_res_table)
            pro_hot1=reduce(operator.add, pro_hot)  #将二维将至一维
            pro_hot1=pro_hot1.tolist()  #将矩阵转化为列表，以便下面的特征合并
            rec_feature=residue_features(resid)
            rec_fea_A.append(pro_hot1+rec_feature+sasa) 
        rec_fea_A=np.array(rec_fea_A)   
    rec_fea_tensor_A = torch.from_numpy(rec_fea_A)
        
    #######################节点特征计算B################3   ppi拼接
    
    value1_B=[]
    res_list_B=[]
    value2_B=[]
    value3_B=[]
    res_list2_B=[]
    with open(all_path_B_sasa,'r') as rec_file:
            line = rec_file.readlines()
            for x in line:
                if x[0:3] =='SEQ':
                    x=x.strip()
                    resid=x[12:16]   #氨基酸的名称
                    sasa_value=x[19:26]  #溶剂可及表面积
                    dd=x[6:11].strip()   #氨基酸号
                    #print(dd,resid,sasa_value)
                    value1_B.append(sasa_value)
                    res_list_B.append(resid)
                    
                    if dd in ppi_resid_B:
                        value3_B.append(sasa_value)
                        res_list2_B.append(resid)
    maxnum=float(max(value1_B))
    minnum=float(min(value1_B))
    internal_value=maxnum-minnum
    for x1 in value3_B:  #sasa
        x1=float(x1)
        final_value=round((x1-minnum)/internal_value,4) 
        value2_B.append(final_value) 
    
    rec_fea_B=[]
    if len(value2_B)==len(res_list2_B): 
        for m in range(len(value2_B)):
            sasa=[value2_B[m]] #sasa为归一化后的值
            pro_seq=[res_list2_B[m]]  #氨基酸名称
            resid=res_list2_B[m]
            pro_hot=np.zeros((1,len(pro_res_table)))  
            for i in range(len(pro_seq)):  #i=1
                pro_hot[i,] = one_of_k_encoding(pro_seq[i], pro_res_table)
            pro_hot1=reduce(operator.add, pro_hot)  #将二维将至一维
            pro_hot1=pro_hot1.tolist()  #将矩阵转化为列表，以便下面的特征合并
            rec_feature=residue_features(resid)
            rec_fea_B.append(pro_hot1+rec_feature+sasa) 
        rec_fea_B=np.array(rec_fea_B)   
    rec_fea_tensor_B = torch.from_numpy(rec_fea_B)
  
    rec_lig_feature = torch.cat((rec_fea_tensor_A, rec_fea_tensor_B), dim=0)
    #print('初步合并后的特征矩阵大小为：',np.shape(rec_lig_feature))
    
    #print(np.shape(esm_all))
    final_feature = torch.cat((rec_lig_feature, esm_all), dim=1)
    #('最后合并后的特征矩阵的大小为：',np.shape(final_feature))
  
    #################################################3333距离特征计算##############################################
    ca_accord_rec_A=[]
    residues_A = {} 
    a=0
    with open(ppi_path_A, 'r') as file:  
        for line in file:  
            if line.startswith('ATOM'):  
                            # 解析PDB行的关键信息  
                            atom_name = line[12:16].strip()  
                            residue_name = line[17:20].strip()  
                            chain_id = line[21].strip()  
                            residue_number = (line[22:27].strip())  
                            x = float(line[30:38].strip())  
                            y = float(line[38:46].strip())  
                            z = float(line[46:54].strip())  
                            
                            if atom_name == 'C': ##太离谱了，有的没有CA有的多个CA,....................................... 
                                # 如果这是当前氨基酸的第一个CA，则存储它  
                                a+=1
                                if (chain_id, residue_number) not in residues_A:  
                                    residues_A[(chain_id, residue_number)] = (x, y, z)  
    for (chain_id, residue_number), (x, y, z) in residues_A.items():  
            ca_accord_rec_A.append([x]+[y]+[z])
            #print(residues)            
            #print(ca_accord_rec)
            a+=1
    ca_accord_rec_A=np.array(ca_accord_rec_A)
    dis_rec_rec_A = distance_matrix(ca_accord_rec_A, ca_accord_rec_A)
        #算出来的距离进行处理，受体-受体和配体-配体之间的距离小于4.5为1，受体-配体之间的距离小于10为1
    for ii in np.nditer(dis_rec_rec_A,op_flags=['readwrite']):
            if ii >8.0:
                ii[...]=0
            else:
                ii[...]=1
                
    a1=rec_fea_tensor_A.shape
    a2=dis_rec_rec_A.shape
    a11=a1[0]
    a22=a2[0]
    #print(f'A链的特征矩阵的大小为:{a1},A链的邻接矩阵的小为{a2}')
    if a11!=a22:
            print(numm,'A链有问题###################################################################')
            print(a1)
            print(a2)
    sA=np.shape(dis_rec_rec_A)
    lenth1=sA[0]
    width1=sA[1]
    
    ca_accord_rec_B=[]
    residues_B = {} 
    a=0
    with open(ppi_path_B, 'r') as file:  
        for line in file:  
            if line.startswith('ATOM'):  
                            # 解析PDB行的关键信息  
                atom_name = line[12:16].strip()  
                residue_name = line[17:20].strip()  
                chain_id = line[21].strip()  
                residue_number = (line[22:27].strip())  
                x = float(line[30:38].strip())  
                y = float(line[38:46].strip())  
                z = float(line[46:54].strip())  
                if atom_name == 'C': ##太离谱了，有的没有CA有的多个CA,....................................... 
                                # 如果这是当前氨基酸的第一个CA，则存储它  
                                a+=1
                                if (chain_id, residue_number) not in residues_B:  
                                    residues_B[(chain_id, residue_number)] = (x, y, z)  
    for (chain_id, residue_number), (x, y, z) in residues_B.items():  
            ca_accord_rec_B.append([x]+[y]+[z])
            #print(residues)            
            #print(ca_accord_rec)
            a+=1
    ca_accord_rec_B=np.array(ca_accord_rec_B)
    dis_rec_rec_B = distance_matrix(ca_accord_rec_B, ca_accord_rec_B)
        #算出来的距离进行处理，受体-受体和配体-配体之间的距离小于4.5为1，受体-配体之间的距离小于10为1
    for ii in np.nditer(dis_rec_rec_B,op_flags=['readwrite']):
            if ii >8.0:
                ii[...]=0
            else:
                ii[...]=1
    a1=rec_fea_tensor_B.shape
    a2=dis_rec_rec_B.shape
    a11=a1[0]
    a22=a2[0]
    #print(f'B链的特征矩阵的大小为:{a1},B链的邻接矩阵的小为{a2}')
    if a11!=a22:
            print(numm,'B链有问题###################################################################')
            #print(a1)
            #print(a2)
    sB=np.shape(dis_rec_rec_B)
    lenth2=sB[0]
    width2=sB[1]
    #print(f'lenth2的长度为：',lenth2,'lenth1的长度为：',lenth1)
    combined_matrix = np.zeros((lenth1+lenth2, lenth1+lenth2))
    combined_matrix[:lenth1, :lenth1] = dis_rec_rec_A
    combined_matrix[lenth1:, lenth1:] = dis_rec_rec_B
    
    #print('合并后的邻接矩阵大小combined_matrix为：',np.shape(combined_matrix))
    
    exposed_rec1, sasa_data_rec1 = calculate_exposed_residues(ppi_path_A_sasa, ppi_path_A)
    exposed_rec2, sasa_data_rec2 = calculate_exposed_residues(ppi_path_B_sasa, ppi_path_B)
    #frequency_matrix = read_frequency_table(frequency_file_path)
    adj_matrix = np.zeros((len(exposed_rec1),len(exposed_rec2)))
    gly_residue=get_residue(glycan_path_A_sasa)
    A_residues=get_residue(ppi_path_A_sasa)
    B_residues=get_residue(ppi_path_B_sasa)
    index=get_index(gly_residue,A_residues)
    
    for i,idx1 in enumerate(exposed_rec1):
        if i in index:
            for j in range(len(B_residues)):
                adj_matrix[i,j] = 1
            
    for i in range(len(A_residues)): 
        for j in range(len(B_residues)):
            combined_matrix[i,lenth1+j] =adj_matrix[i,j]   
            combined_matrix[lenth1+ j, i] = adj_matrix[i, j]
    
    
    #print('合并后的邻接矩阵大小combined_matrix2为：',np.shape(combined_matrix))
    ################################标签计算-all ####################################################
    all_target=[]
    with open(ppi_path_A_sasa,'r') as tar_file:
        line=tar_file.readlines()
        for x in line:
            if x[0:3] =='SEQ':
                x=x.strip()
                resid=x[12:16]   #氨基酸的名称
                dd=x[6:11].strip()   #氨基酸号
                chain_id=x[4]
                all_target.append((chain_id,dd,resid))
                
    with open(ppi_path_B_sasa,'r') as tar_file2:
        line=tar_file2.readlines()
        for x in line:
            if x[0:3] =='SEQ':
                x=x.strip()
                resid=x[12:16]   #氨基酸的名称
                dd=x[6:11].strip()   #氨基酸号
                chain_id=x[4]
                all_target.append((chain_id,dd,resid))
    pos_target=[]   #glycan——B
    with open(glycan_path_B_sasa,'r') as pos_file:
        line=pos_file.readlines()
        for x in line:
            if x[0:3] =='SEQ':
                x=x.strip()
                resid=x[12:16]   #氨基酸的名称
                dd=x[6:11].strip()   #氨基酸号
                chain_id=x[4]
                pos_target.append((chain_id,dd,resid))
                
    tt=all_target
    new_target=all_target
    print('all_target的大小为：',len(all_target))
    print('tt的大小为：',len(tt))
    print('new_target的大小为：',len(new_target))
    for nu,i55 in enumerate(tt):
        if i55 in pos_target:
            new_target[nu]=1
        else:
            new_target[nu]=0
            
    #print(all_target)#
    print('最后合并后的特征矩阵的大小为：',np.shape(final_feature))
    print('最后合并后的距离矩阵的大小为：',np.shape(combined_matrix))
    print('最后合并后的标签的大小为：',np.shape(new_target))
    if np.shape(final_feature)[0] != np.shape(new_target)[0]:
        print('有问题')
    #target_all=new_target
    input_file=os.path.join(save_npz_path,"%s.npz"%numm)
    np.savez(input_file,  H=final_feature, A1=combined_matrix, T=new_target)
# Out:
# 1A0H_1_A_B
# /tmp/ipykernel_61362/2507317142.py:27: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   esm_feature=torch.load(f'/data5_large/home/yanzh/deeplearn/graph_residue/my_data/protein_new_3222/dataset_shuanglian_buchong/a_picture/train/hebin_esm/{numm}_{A_chain}.pt')
# 85
# 71
# all_target的大小为： 156
# tt的大小为： 156
# new_target的大小为： 156
# 最后合并后的特征矩阵的大小为： torch.Size([156, 1310])
# 最后合并后的距离矩阵的大小为： (156, 156)
# 最后合并后的标签的大小为： (156,)
# 1A0H_1_D_E
# 81
# 71
# all_target的大小为： 152
# tt的大小为： 152
# new_target的大小为： 152
# 最后合并后的特征矩阵的大小为： torch.Size([152, 1310])
# 最后合并后的距离矩阵的大小为： (152, 152)
# 最后合并后的标签的大小为： (152,)
# 1APY_1_C_D
# 63
# 73
# all_target的大小为： 136
# tt的大小为： 136
# new_target的大小为： 136
# 最后合并后的特征矩阵的大小为： torch.Size([136, 1310])
# 最后合并后的距离矩阵的大小为： (136, 136)
# 最后合并后的标签的大小为： (136,)
# 1APZ_1_C_D
# 65
# 73
# all_target的大小为： 138
# tt的大小为： 138
# new_target的大小为： 138
# 最后合并后的特征矩阵的大小为： torch.Size([138, 1310])
# 最后合并后的距离矩阵的大小为： (138, 138)
# 最后合并后的标签的大小为： (138,)
# 1BCR_1_A_B
# 85
# 114
# all_target的大小为： 199
# tt的大小为： 199
# new_target的大小为： 199
# 最后合并后的特征矩阵的大小为： torch.Size([199, 1310])
# 最后合并后的距离矩阵的大小为： (199, 199)
# 最后合并后的标签的大小为： (199,)
# 1BCR_1_B_A
# 115
# 86
# all_target的大小为： 201
# tt的大小为： 201
# new_target的大小为： 201
# 最后合并后的特征矩阵的大小为： torch.Size([201, 1310])
# 最后合并后的距离矩阵的大小为： (201, 201)
# 最后合并后的标签的大小为： (201,)
# 1CE7_1_A_B
# 32
# 31
# all_target的大小为： 63
# tt的大小为： 63
# new_target的大小为： 63
# 最后合并后的特征矩阵的大小为： torch.Size([63, 1310])
# 最后合并后的距离矩阵的大小为： (63, 63)
# 最后合并后的标签的大小为： (63,)
# 1CXP_1_A_D
# 10
# 9
# all_target的大小为： 19
# tt的大小为： 19
# new_target的大小为： 19
# 最后合并后的特征矩阵的大小为： torch.Size([19, 1310])
# 最后合并后的距离矩阵的大小为： (19, 19)
# 最后合并后的标签的大小为： (19,)
# 1CXP_1_B_C
# 10
# 10
# all_target的大小为： 20
# tt的大小为： 20
# new_target的大小为： 20
# 最后合并后的特征矩阵的大小为： torch.Size([20, 1310])
# 最后合并后的距离矩阵的大小为： (20, 20)
# 最后合并后的标签的大小为： (20,)
# 1D2V_1_A_D
# 10
# 9
# all_target的大小为： 19
# tt的大小为： 19
# new_target的大小为： 19
# 最后合并后的特征矩阵的大小为： torch.Size([19, 1310])
# 最后合并后的距离矩阵的大小为： (19, 19)
# 最后合并后的标签的大小为： (19,)
# 1D2V_1_B_C
# 10
# 9
# all_target的大小为： 19
# tt的大小为： 19
# new_target的大小为： 19
# 最后合并后的特征矩阵的大小为： torch.Size([19, 1310])
# 最后合并后的距离矩阵的大小为： (19, 19)
# 最后合并后的标签的大小为： (19,)
# 1D5L_1_A_D
# 10
# 9
# all_target的大小为： 19
# tt的大小为： 19
# new_target的大小为： 19
# 最后合并后的特征矩阵的大小为： torch.Size([19, 1310])
# 最后合并后的距离矩阵的大小为： (19, 19)
# 最后合并后的标签的大小为： (19,)
# 1D5L_1_B_C
# 10
# 10
# all_target的大小为： 20
# tt的大小为： 20
# new_target的大小为： 20
# 最后合并后的特征矩阵的大小为： torch.Size([20, 1310])
# 最后合并后的距离矩阵的大小为： (20, 20)
# 最后合并后的标签的大小为： (20,)
# 1D5M_1_B_A
# 65
# 51
# all_target的大小为： 116
# tt的大小为： 116
# new_target的大小为： 116
# 最后合并后的特征矩阵的大小为： torch.Size([116, 1310])
# 最后合并后的距离矩阵的大小为： (116, 116)
# 最后合并后的标签的大小为： (116,)
# 1D7W_1_A_D
# 10
# 9
# all_target的大小为： 19
# tt的大小为： 19
# new_target的大小为： 19
# 最后合并后的特征矩阵的大小为： torch.Size([19, 1310])
# 最后合并后的距离矩阵的大小为： (19, 19)
# 最后合并后的标签的大小为： (19,)
# 1D7W_1_B_C
# 10
# 9
# all_target的大小为： 19
# tt的大小为： 19
# new_target的大小为： 19
# 最后合并后的特征矩阵的大小为： torch.Size([19, 1310])
# 最后合并后的距离矩阵的大小为： (19, 19)
# 最后合并后的标签的大小为： (19,)
# 1DAN_1_U_L
# 18
# 22
# all_target的大小为： 40
# tt的大小为： 40
# new_target的大小为： 40
# 最后合并后的特征矩阵的大小为： torch.Size([40, 1310])
# 最后合并后的距离矩阵的大小为： (40, 40)
# 最后合并后的标签的大小为： (40,)
# 1DE4_1_A_F
# 2
# 4
# all_target的大小为： 6
# tt的大小为： 6
# new_target的大小为： 6
# 最后合并后的特征矩阵的大小为： torch.Size([6, 1310])
# 最后合并后的距离矩阵的大小为： (6, 6)
# 最后合并后的标签的大小为： (6,)
# 1DE4_1_D_C
# 2
# 4
# all_target的大小为： 6
# tt的大小为： 6
# new_target的大小为： 6
# 最后合并后的特征矩阵的大小为： torch.Size([6, 1310])
# 最后合并后的距离矩阵的大小为： (6, 6)
# 最后合并后的标签的大小为： (6,)
# 1DLH_1_B_A
# 65
# 55
# all_target的大小为： 120
# tt的大小为： 120
# new_target的大小为： 120
# 最后合并后的特征矩阵的大小为： torch.Size([120, 1310])
# 最后合并后的距离矩阵的大小为： (120, 120)
# 最后合并后的标签的大小为： (120,)
# 1DLH_1_B_D
# 11
# 10
# all_target的大小为： 21
# tt的大小为： 21
# new_target的大小为： 21
# 最后合并后的特征矩阵的大小为： torch.Size([21, 1310])
# 最后合并后的距离矩阵的大小为： (21, 21)
# 最后合并后的标签的大小为： (21,)
# 1DLH_1_E_A
# 13
# 12
# all_target的大小为： 25
# tt的大小为： 25
# new_target的大小为： 25
# 最后合并后的特征矩阵的大小为： torch.Size([25, 1310])
# 最后合并后的距离矩阵的大小为： (25, 25)
# 最后合并后的标签的大小为： (25,)
# 1DLH_1_E_D
# 65
# 55
# all_target的大小为： 120
# tt的大小为： 120
# new_target的大小为： 120
# 最后合并后的特征矩阵的大小为： torch.Size([120, 1310])
# 最后合并后的距离矩阵的大小为： (120, 120)
# 最后合并后的标签的大小为： (120,)
# 1DNU_1_A_D
# 10
# 9
# all_target的大小为： 19
# tt的大小为： 19
# new_target的大小为： 19
# 最后合并后的特征矩阵的大小为： torch.Size([19, 1310])
# 最后合并后的距离矩阵的大小为： (19, 19)
# 最后合并后的标签的大小为： (19,)
# 1DNU_1_B_C
# 10
# 10
# all_target的大小为： 20
# tt的大小为： 20
# new_target的大小为： 20
# 最后合并后的特征矩阵的大小为： torch.Size([20, 1310])
# 最后合并后的距离矩阵的大小为： (20, 20)
# 最后合并后的标签的大小为： (20,)
# 1DNW_1_A_D
# 10
# 9
# all_target的大小为： 19
# tt的大小为： 19
# new_target的大小为： 19
# 最后合并后的特征矩阵的大小为： torch.Size([19, 1310])
# 最后合并后的距离矩阵的大小为： (19, 19)
# 最后合并后的标签的大小为： (19,)
# 1DNW_1_B_C
# 10
# 10
# all_target的大小为： 20
# tt的大小为： 20
# new_target的大小为： 20
# 最后合并后的特征矩阵的大小为： torch.Size([20, 1310])
# 最后合并后的距离矩阵的大小为： (20, 20)
# 最后合并后的标签的大小为： (20,)
# 1E4K_1_C_B
# 14
# 12
# all_target的大小为： 26
# tt的大小为： 26
# new_target的大小为： 26
# 最后合并后的特征矩阵的大小为： torch.Size([26, 1310])
# 最后合并后的距离矩阵的大小为： (26, 26)
# 最后合并后的标签的大小为： (26,)
# 1F3J_1_E_D
# 64
# 57
# all_target的大小为： 121
# tt的大小为： 121
# new_target的大小为： 121
# 最后合并后的特征矩阵的大小为： torch.Size([121, 1310])
# 最后合并后的距离矩阵的大小为： (121, 121)
# 最后合并后的标签的大小为： (121,)
# 1F6A_1_A_B
# 13
# 8
# all_target的大小为： 21
# tt的大小为： 21
# new_target的大小为： 21
# 最后合并后的特征矩阵的大小为： torch.Size([21, 1310])
# 最后合并后的距离矩阵的大小为： (21, 21)
# 最后合并后的标签的大小为： (21,)
# 1F6A_1_D_A
# 10
# 11
# all_target的大小为： 21
# tt的大小为： 21
# new_target的大小为： 21
# 最后合并后的特征矩阵的大小为： torch.Size([21, 1310])
# 最后合并后的距离矩阵的大小为： (21, 21)
# 最后合并后的标签的大小为： (21,)
# 1FAK_1_T_L
# 29
# 31
# all_target的大小为： 60
# tt的大小为： 60
# new_target的大小为： 60
# 最后合并后的特征矩阵的大小为： torch.Size([60, 1310])
# 最后合并后的距离矩阵的大小为： (60, 60)
# 最后合并后的标签的大小为： (60,)
# 1FE8_1_A_H
# 11
# 15
# all_target的大小为： 26
# tt的大小为： 26
# new_target的大小为： 26
# 最后合并后的特征矩阵的大小为： torch.Size([26, 1310])
# 最后合并后的距离矩阵的大小为： (26, 26)
# 最后合并后的标签的大小为： (26,)
# 1FL7_1_B_A
# 48
# 53
# all_target的大小为： 101
# tt的大小为： 101
# new_target的大小为： 101
# 最后合并后的特征矩阵的大小为： torch.Size([101, 1310])
# 最后合并后的距离矩阵的大小为： (101, 101)
# 最后合并后的标签的大小为： (101,)
# 1FYT_1_B_A
# 65
# 53
# all_target的大小为： 118
# tt的大小为： 118
# new_target的大小为： 118
# 最后合并后的特征矩阵的大小为： torch.Size([118, 1310])
# 最后合并后的距离矩阵的大小为： (118, 118)
# 最后合并后的标签的大小为： (118,)
# 1GXS_1_A_B
# 91
# 125
# all_target的大小为： 216
# tt的大小为： 216
# new_target的大小为： 216
# 最后合并后的特征矩阵的大小为： torch.Size([216, 1310])
# 最后合并后的距离矩阵的大小为： (216, 216)
# 最后合并后的标签的大小为： (216,)
# 1GXS_1_B_A
# 126
# 92
# all_target的大小为： 218
# tt的大小为： 218
# new_target的大小为： 218
# 最后合并后的特征矩阵的大小为： torch.Size([218, 1310])
# 最后合并后的距离矩阵的大小为： (218, 218)
# 最后合并后的标签的大小为： (218,)
# 1GXS_1_C_D
# 91
# 127
# all_target的大小为： 218
# tt的大小为： 218
# new_target的大小为： 218
# 最后合并后的特征矩阵的大小为： torch.Size([218, 1310])
# 最后合并后的距离矩阵的大小为： (218, 218)
# 最后合并后的标签的大小为： (218,)
# 1GXS_1_D_C
# 128
# 92
# all_target的大小为： 220
# tt的大小为： 220
# new_target的大小为： 220
# 最后合并后的特征矩阵的大小为： torch.Size([220, 1310])
# 最后合并后的距离矩阵的大小为： (220, 220)
# 最后合并后的标签的大小为： (220,)
# 1H15_1_B_A
# 65
# 52
# all_target的大小为： 117
# tt的大小为： 117
# new_target的大小为： 117
# 最后合并后的特征矩阵的大小为： torch.Size([117, 1310])
# 最后合并后的距离矩阵的大小为： (117, 117)
# 最后合并后的标签的大小为： (117,)
# 1HCN_1_B_A
# 49
# 49
# all_target的大小为： 98
# tt的大小为： 98
# new_target的大小为： 98
# 最后合并后的特征矩阵的大小为： torch.Size([98, 1310])
# 最后合并后的距离矩阵的大小为： (98, 98)
# 最后合并后的标签的大小为： (98,)
# 1HRP_1_B_A
# 48
# 51
# all_target的大小为： 99
# tt的大小为： 99
# new_target的大小为： 99
# 最后合并后的特征矩阵的大小为： torch.Size([99, 1310])
# 最后合并后的距离矩阵的大小为： (99, 99)
# 最后合并后的标签的大小为： (99,)
# 1I1A_1_C_A
# 17
# 21
# all_target的大小为： 38
# tt的大小为： 38
# new_target的大小为： 38
# 最后合并后的特征矩阵的大小为： torch.Size([38, 1310])
# 最后合并后的距离矩阵的大小为： (38, 38)
# 最后合并后的标签的大小为： (38,)
# 1I1A_1_D_C
# 34
# 32
# all_target的大小为： 66
# tt的大小为： 66
# new_target的大小为： 66
# 最后合并后的特征矩阵的大小为： torch.Size([66, 1310])
# 最后合并后的距离矩阵的大小为： (66, 66)
# 最后合并后的标签的大小为： (66,)
# 1I3R_1_B_A
# 79
# 74
# all_target的大小为： 153
# tt的大小为： 153
# new_target的大小为： 153
# 最后合并后的特征矩阵的大小为： torch.Size([153, 1310])
# 最后合并后的距离矩阵的大小为： (153, 153)
# 最后合并后的标签的大小为： (153,)
# 1I3R_1_B_C
# 5
# 6
# all_target的大小为： 11
# tt的大小为： 11
# new_target的大小为： 11
# 最后合并后的特征矩阵的大小为： torch.Size([11, 1310])
# 最后合并后的距离矩阵的大小为： (11, 11)
# 最后合并后的标签的大小为： (11,)
# 1I3R_1_D_A
# 6
# 7
# all_target的大小为： 13
# tt的大小为： 13
# new_target的大小为： 13
# 最后合并后的特征矩阵的大小为： torch.Size([13, 1310])
# 最后合并后的距离矩阵的大小为： (13, 13)
# 最后合并后的标签的大小为： (13,)
# 1I3R_1_D_C
# 78
# 75
# all_target的大小为： 153
# tt的大小为： 153
# new_target的大小为： 153
# 最后合并后的特征矩阵的大小为： torch.Size([153, 1310])
# 最后合并后的距离矩阵的大小为： (153, 153)
# 最后合并后的标签的大小为： (153,)
# 1I3R_1_F_E
# 78
# 75
# all_target的大小为： 153
# tt的大小为： 153
# new_target的大小为： 153
# 最后合并后的特征矩阵的大小为： torch.Size([153, 1310])
# 最后合并后的距离矩阵的大小为： (153, 153)
# 最后合并后的标签的大小为： (153,)
# 1I3R_1_F_G
# 6
# 8
# all_target的大小为： 14
# tt的大小为： 14
# new_target的大小为： 14
# 最后合并后的特征矩阵的大小为： torch.Size([14, 1310])
# 最后合并后的距离矩阵的大小为： (14, 14)
# 最后合并后的标签的大小为： (14,)
# 1I3R_1_F_H
# 21
# 20
# all_target的大小为： 41
# tt的大小为： 41
# new_target的大小为： 41
# 最后合并后的特征矩阵的大小为： torch.Size([41, 1310])
# 最后合并后的距离矩阵的大小为： (41, 41)
# 最后合并后的标签的大小为： (41,)
# 1I3R_1_H_E
# 6
# 8
# all_target的大小为： 14
# tt的大小为： 14
# new_target的大小为： 14
# 最后合并后的特征矩阵的大小为： torch.Size([14, 1310])
# 最后合并后的距离矩阵的大小为： (14, 14)
# 最后合并后的标签的大小为： (14,)
# 1I3R_1_H_G
# 80
# 80
# all_target的大小为： 160
# tt的大小为： 160
# new_target的大小为： 160
# 最后合并后的特征矩阵的大小为： torch.Size([160, 1310])
# 最后合并后的距离矩阵的大小为： (160, 160)
# 最后合并后的标签的大小为： (160,)
# 1IEA_1_B_A
# 80
# 78
# all_target的大小为： 158
# tt的大小为： 158
# new_target的大小为： 158
# 最后合并后的特征矩阵的大小为： torch.Size([158, 1310])
# 最后合并后的距离矩阵的大小为： (158, 158)
# 最后合并后的标签的大小为： (158,)
# 1J9C_1_T_L
# 21
# 25
# all_target的大小为： 46
# tt的大小为： 46
# new_target的大小为： 46
# 最后合并后的特征矩阵的大小为： torch.Size([46, 1310])
# 最后合并后的距离矩阵的大小为： (46, 46)
# 最后合并后的标签的大小为： (46,)
# 1JV2_1_A_B
# 78
# 83
# all_target的大小为： 161
# tt的大小为： 161
# new_target的大小为： 161
# 最后合并后的特征矩阵的大小为： torch.Size([161, 1310])
# 最后合并后的距离矩阵的大小为： (161, 161)
# 最后合并后的标签的大小为： (161,)
# 1K2D_1_B_A
# 64
# 60
# all_target的大小为： 124
# tt的大小为： 124
# new_target的大小为： 124
# 最后合并后的特征矩阵的大小为： torch.Size([124, 1310])
# 最后合并后的距离矩阵的大小为： (124, 124)
# 最后合并后的标签的大小为： (124,)
# 1K3B_1_B_A
# 23
# 20
# all_target的大小为： 43
# tt的大小为： 43
# new_target的大小为： 43
# 最后合并后的特征矩阵的大小为： torch.Size([43, 1310])
# 最后合并后的距离矩阵的大小为： (43, 43)
# 最后合并后的标签的大小为： (43,)
# 1K3B_1_C_A
# 9
# 9
# all_target的大小为： 18
# tt的大小为： 18
# new_target的大小为： 18
# 最后合并后的特征矩阵的大小为： torch.Size([18, 1310])
# 最后合并后的距离矩阵的大小为： (18, 18)
# 最后合并后的标签的大小为： (18,)
# 1KEN_1_H_C
# 6
# 13
# all_target的大小为： 19
# tt的大小为： 19
# new_target的大小为： 19
# 最后合并后的特征矩阵的大小为： torch.Size([19, 1310])
# 最后合并后的距离矩阵的大小为： (19, 19)
# 最后合并后的标签的大小为： (19,)
# 1KEN_1_T_E
# 3
# 10
# all_target的大小为： 13
# tt的大小为： 13
# new_target的大小为： 13
# 最后合并后的特征矩阵的大小为： torch.Size([13, 1310])
# 最后合并后的距离矩阵的大小为： (13, 13)
# 最后合并后的标签的大小为： (13,)
# 1KTD_1_B_A
# 81
# 80
# all_target的大小为： 161
# tt的大小为： 161
# new_target的大小为： 161
# 最后合并后的特征矩阵的大小为： torch.Size([161, 1310])
# 最后合并后的距离矩阵的大小为： (161, 161)
# 最后合并后的标签的大小为： (161,)
# 1L5G_1_A_B
# 78
# 80
# all_target的大小为： 158
# tt的大小为： 158
# new_target的大小为： 158
# 最后合并后的特征矩阵的大小为： torch.Size([158, 1310])
# 最后合并后的距离矩阵的大小为： (158, 158)
# 最后合并后的标签的大小为： (158,)
# 1LGB_1_A_C
# 5
# 16
# all_target的大小为： 21
# tt的大小为： 21
# new_target的大小为： 21
# 最后合并后的特征矩阵的大小为： torch.Size([21, 1310])
# 最后合并后的距离矩阵的大小为： (21, 21)
# 最后合并后的标签的大小为： (21,)
# 1LNU_1_B_A
# 77
# 82
# all_target的大小为： 159
# tt的大小为： 159
# new_target的大小为： 159
# 最后合并后的特征矩阵的大小为： torch.Size([159, 1310])
# 最后合并后的距离矩阵的大小为： (159, 159)
# 最后合并后的标签的大小为： (159,)
# 1LYA_1_B_A
# 75
# 73
# all_target的大小为： 148
# tt的大小为： 148
# new_target的大小为： 148
# 最后合并后的特征矩阵的大小为： torch.Size([148, 1310])
# 最后合并后的距离矩阵的大小为： (148, 148)
# 最后合并后的标签的大小为： (148,)
# 1LYA_1_D_C
# 75
# 76
# all_target的大小为： 151
# tt的大小为： 151
# new_target的大小为： 151
# 最后合并后的特征矩阵的大小为： torch.Size([151, 1310])
# 最后合并后的距离矩阵的大小为： (151, 151)
# 最后合并后的标签的大小为： (151,)
# 1LYB_1_B_A
# 74
# 74
# all_target的大小为： 148
# tt的大小为： 148
# new_target的大小为： 148
# 最后合并后的特征矩阵的大小为： torch.Size([148, 1310])
# 最后合并后的距离矩阵的大小为： (148, 148)
# 最后合并后的标签的大小为： (148,)
# 1M1X_1_A_B
# 75
# 84
# all_target的大小为： 159
# tt的大小为： 159
# new_target的大小为： 159
# 最后合并后的特征矩阵的大小为： torch.Size([159, 1310])
# 最后合并后的距离矩阵的大小为： (159, 159)
# 最后合并后的标签的大小为： (159,)
# 1M2T_1_A_B
# 38
# 42
# all_target的大小为： 80
# tt的大小为： 80
# new_target的大小为： 80
# 最后合并后的特征矩阵的大小为： torch.Size([80, 1310])
# 最后合并后的距离矩阵的大小为： (80, 80)
# 最后合并后的标签的大小为： (80,)
# 1MHL_1_A_D
# 10
# 9
# all_target的大小为： 19
# tt的大小为： 19
# new_target的大小为： 19
# 最后合并后的特征矩阵的大小为： torch.Size([19, 1310])
# 最后合并后的距离矩阵的大小为： (19, 19)
# 最后合并后的标签的大小为： (19,)
# 1MHL_1_B_C
# 10
# 9
# all_target的大小为： 19
# tt的大小为： 19
# new_target的大小为： 19
# 最后合并后的特征矩阵的大小为： torch.Size([19, 1310])
# 最后合并后的距离矩阵的大小为： (19, 19)
# 最后合并后的标签的大小为： (19,)
# 1MOX_1_C_A
# 44
# 31
# all_target的大小为： 75
# tt的大小为： 75
# new_target的大小为： 75
# 最后合并后的特征矩阵的大小为： torch.Size([75, 1310])
# 最后合并后的距离矩阵的大小为： (75, 75)
# 最后合并后的标签的大小为： (75,)
# 1MYP_1_A_D
# 8
# 7
# all_target的大小为： 15
# tt的大小为： 15
# new_target的大小为： 15
# 最后合并后的特征矩阵的大小为： torch.Size([15, 1310])
# 最后合并后的距离矩阵的大小为： (15, 15)
# 最后合并后的标签的大小为： (15,)
# 1MYP_1_B_C
# 9
# 7
# all_target的大小为： 16
# tt的大小为： 16
# new_target的大小为： 16
# 最后合并后的特征矩阵的大小为： torch.Size([16, 1310])
# 最后合并后的距离矩阵的大小为： (16, 16)
# 最后合并后的标签的大小为： (16,)
# 1NFD_1_D_C
# 60
# 51
# all_target的大小为： 111
# tt的大小为： 111
# new_target的大小为： 111
# 最后合并后的特征矩阵的大小为： torch.Size([111, 1310])
# 最后合并后的距离矩阵的大小为： (111, 111)
# 最后合并后的标签的大小为： (111,)
# 1NFD_1_H_D
# 10
# 11
# all_target的大小为： 21
# tt的大小为： 21
# new_target的大小为： 21
# 最后合并后的特征矩阵的大小为： torch.Size([21, 1310])
# 最后合并后的距离矩阵的大小为： (21, 21)
# 最后合并后的标签的大小为： (21,)
# 1NP0_1_A_C
# 52
# 44
# all_target的大小为： 96
# tt的大小为： 96
# new_target的大小为： 96
# 最后合并后的特征矩阵的大小为： torch.Size([96, 1310])
# 最后合并后的距离矩阵的大小为： (96, 96)
# 最后合并后的标签的大小为： (96,)
# 1NQL_1_B_A
# 22
# 23
# all_target的大小为： 45
# tt的大小为： 45
# new_target的大小为： 45
# 最后合并后的特征矩阵的大小为： torch.Size([45, 1310])
# 最后合并后的距离矩阵的大小为： (45, 45)
# 最后合并后的标签的大小为： (45,)
# 1O7D_1_A_C
# 20
# 30
# all_target的大小为： 50
# tt的大小为： 50
# new_target的大小为： 50
# 最后合并后的特征矩阵的大小为： torch.Size([50, 1310])
# 最后合并后的距离矩阵的大小为： (50, 50)
# 最后合并后的标签的大小为： (50,)
# 1O7D_1_A_D
# 22
# 28
# all_target的大小为： 50
# tt的大小为： 50
# new_target的大小为： 50
# 最后合并后的特征矩阵的大小为： torch.Size([50, 1310])
# 最后合并后的距离矩阵的大小为： (50, 50)
# 最后合并后的标签的大小为： (50,)
# 1O7D_1_B_C
# 35
# 24
# all_target的大小为： 59
# tt的大小为： 59
# new_target的大小为： 59
# 最后合并后的特征矩阵的大小为： torch.Size([59, 1310])
# 最后合并后的距离矩阵的大小为： (59, 59)
# 最后合并后的标签的大小为： (59,)
# 1O7D_1_B_D
# 47
# 28
# all_target的大小为： 75
# tt的大小为： 75
# new_target的大小为： 75
# 最后合并后的特征矩阵的大小为： torch.Size([75, 1310])
# 最后合并后的距离矩阵的大小为： (75, 75)
# 最后合并后的标签的大小为： (75,)
# 1O7D_1_C_D
# 37
# 48
# all_target的大小为： 85
# tt的大小为： 85
# new_target的大小为： 85
# 最后合并后的特征矩阵的大小为： torch.Size([85, 1310])
# 最后合并后的距离矩阵的大小为： (85, 85)
# 最后合并后的标签的大小为： (85,)
# 1O7D_1_D_C
# 47
# 42
# all_target的大小为： 89
# tt的大小为： 89
# new_target的大小为： 89
# 最后合并后的特征矩阵的大小为： torch.Size([89, 1310])
# 最后合并后的距离矩阵的大小为： (89, 89)
# 最后合并后的标签的大小为： (89,)
# 1ONK_1_A_B
# 39
# 43
# all_target的大小为： 82
# tt的大小为： 82
# new_target的大小为： 82
# 最后合并后的特征矩阵的大小为： torch.Size([82, 1310])
# 最后合并后的距离矩阵的大小为： (82, 82)
# 最后合并后的标签的大小为： (82,)
# 1OQL_1_A_B
# 40
# 42
# all_target的大小为： 82
# tt的大小为： 82
# new_target的大小为： 82
# 最后合并后的特征矩阵的大小为： torch.Size([82, 1310])
# 最后合并后的距离矩阵的大小为： (82, 82)
# 最后合并后的标签的大小为： (82,)
# 1PC8_1_A_B
# 39
# 33
# all_target的大小为： 72
# tt的大小为： 72
# new_target的大小为： 72
# 最后合并后的特征矩阵的大小为： torch.Size([72, 1310])
# 最后合并后的距离矩阵的大小为： (72, 72)
# 最后合并后的标签的大小为： (72,)
# 1PUM_1_A_B
# 40
# 43
# all_target的大小为： 83
# tt的大小为： 83
# new_target的大小为： 83
# 最后合并后的特征矩阵的大小为： torch.Size([83, 1310])
# 最后合并后的距离矩阵的大小为： (83, 83)
# 最后合并后的标签的大小为： (83,)
# 1PUU_1_A_B
# 40
# 42
# all_target的大小为： 82
# tt的大小为： 82
# new_target的大小为： 82
# 最后合并后的特征矩阵的大小为： torch.Size([82, 1310])
# 最后合并后的距离矩阵的大小为： (82, 82)
# 最后合并后的标签的大小为： (82,)
# 1QFW_1_B_A
# 47
# 54
# all_target的大小为： 101
# tt的大小为： 101
# new_target的大小为： 101
# 最后合并后的特征矩阵的大小为： torch.Size([101, 1310])
# 最后合并后的距离矩阵的大小为： (101, 101)
# 最后合并后的标签的大小为： (101,)
# 1QFW_1_M_A
# 4
# 6
# all_target的大小为： 10
# tt的大小为： 10
# new_target的大小为： 10
# 最后合并后的特征矩阵的大小为： torch.Size([10, 1310])
# 最后合并后的距离矩阵的大小为： (10, 10)
# 最后合并后的标签的大小为： (10,)
# 1QLF_1_A_C
# 9
# 34
# all_target的大小为： 43
# tt的大小为： 43
# new_target的大小为： 43
# 最后合并后的特征矩阵的大小为： torch.Size([43, 1310])
# 最后合并后的距离矩阵的大小为： (43, 43)
# 最后合并后的标签的大小为： (43,)
# 1SGF_1_B_G
# 29
# 15
# all_target的大小为： 44
# tt的大小为： 44
# new_target的大小为： 44
# 最后合并后的特征矩阵的大小为： torch.Size([44, 1310])
# 最后合并后的距离矩阵的大小为： (44, 44)
# 最后合并后的标签的大小为： (44,)
# 1SGF_1_Y_Z
# 33
# 15
# all_target的大小为： 48
# tt的大小为： 48
# new_target的大小为： 48
# 最后合并后的特征矩阵的大小为： torch.Size([48, 1310])
# 最后合并后的距离矩阵的大小为： (48, 48)
# 最后合并后的标签的大小为： (48,)
# 1T83_1_C_A
# 13
# 13
# all_target的大小为： 26
# tt的大小为： 26
# new_target的大小为： 26
# 最后合并后的特征矩阵的大小为： torch.Size([26, 1310])
# 最后合并后的距离矩阵的大小为： (26, 26)
# 最后合并后的标签的大小为： (26,)
# 1T89_1_C_A
# 14
# 9
# all_target的大小为： 23
# tt的大小为： 23
# new_target的大小为： 23
# 最后合并后的特征矩阵的大小为： torch.Size([23, 1310])
# 最后合并后的距离矩阵的大小为： (23, 23)
# 最后合并后的标签的大小为： (23,)
# 1TA3_1_B_A
# 24
# 35
# all_target的大小为： 59
# tt的大小为： 59
# new_target的大小为： 59
# 最后合并后的特征矩阵的大小为： torch.Size([59, 1310])
# 最后合并后的距离矩阵的大小为： (59, 59)
# 最后合并后的标签的大小为： (59,)
# 1TCR_1_B_A
# 58
# 64
# all_target的大小为： 122
# tt的大小为： 122
# new_target的大小为： 122
# 最后合并后的特征矩阵的大小为： torch.Size([122, 1310])
# 最后合并后的距离矩阵的大小为： (122, 122)
# 最后合并后的标签的大小为： (122,)
# 1TFM_1_A_B
# 35
# 30
# all_target的大小为： 65
# tt的大小为： 65
# new_target的大小为： 65
# 最后合并后的特征矩阵的大小为： torch.Size([65, 1310])
# 最后合并后的距离矩阵的大小为： (65, 65)
# 最后合并后的标签的大小为： (65,)
# 1TYE_1_A_B
# 36
# 46
# all_target的大小为： 82
# tt的大小为： 82
# new_target的大小为： 82
# 最后合并后的特征矩阵的大小为： torch.Size([82, 1310])
# 最后合并后的距离矩阵的大小为： (82, 82)
# 最后合并后的标签的大小为： (82,)
# 1U8C_1_A_B
# 73
# 81
# all_target的大小为： 154
# tt的大小为： 154
# new_target的大小为： 154
# 最后合并后的特征矩阵的大小为： torch.Size([154, 1310])
# 最后合并后的距离矩阵的大小为： (154, 154)
# 最后合并后的标签的大小为： (154,)
# 1UVQ_1_B_A
# 67
# 59
# all_target的大小为： 126
# tt的大小为： 126
# new_target的大小为： 126
# 最后合并后的特征矩阵的大小为： torch.Size([126, 1310])
# 最后合并后的距离矩阵的大小为： (126, 126)
# 最后合并后的标签的大小为： (126,)
# 1W0Y_1_T_L
# 30
# 40
# all_target的大小为： 70
# tt的大小为： 70
# new_target的大小为： 70
# 最后合并后的特征矩阵的大小为： torch.Size([70, 1310])
# 最后合并后的距离矩阵的大小为： (70, 70)
# 最后合并后的标签的大小为： (70,)
# 1W1I_1_E_B
# 23
# 27
# all_target的大小为： 50
# tt的大小为： 50
# new_target的大小为： 50
# 最后合并后的特征矩阵的大小为： torch.Size([50, 1310])
# 最后合并后的距离矩阵的大小为： (50, 50)
# 最后合并后的标签的大小为： (50,)
# 1W1I_1_F_A
# 24
# 27
# all_target的大小为： 51
# tt的大小为： 51
# new_target的大小为： 51
# 最后合并后的特征矩阵的大小为： torch.Size([51, 1310])
# 最后合并后的距离矩阵的大小为： (51, 51)
# 最后合并后的标签的大小为： (51,)
# 1W2K_1_T_L
# 29
# 39
# all_target的大小为： 68
# tt的大小为： 68
# new_target的大小为： 68
# 最后合并后的特征矩阵的大小为： torch.Size([68, 1310])
# 最后合并后的距离矩阵的大小为： (68, 68)
# 最后合并后的标签的大小为： (68,)
# 1WHT_1_A_B
# 85
# 118
# all_target的大小为： 203
# tt的大小为： 203
# new_target的大小为： 203
# 最后合并后的特征矩阵的大小为： torch.Size([203, 1310])
# 最后合并后的距离矩阵的大小为： (203, 203)
# 最后合并后的标签的大小为： (203,)
# 1WHT_1_B_A
# 119
# 87
# all_target的大小为： 206
# tt的大小为： 206
# new_target的大小为： 206
# 最后合并后的特征矩阵的大小为： torch.Size([206, 1310])
# 最后合并后的距离矩阵的大小为： (206, 206)
# 最后合并后的标签的大小为： (206,)
# 1WQV_1_T_L
# 28
# 39
# all_target的大小为： 67
# tt的大小为： 67
# new_target的大小为： 67
# 最后合并后的特征矩阵的大小为： torch.Size([67, 1310])
# 最后合并后的距离矩阵的大小为： (67, 67)
# 最后合并后的标签的大小为： (67,)
# 1WSS_1_T_L
# 29
# 40
# all_target的大小为： 69
# tt的大小为： 69
# new_target的大小为： 69
# 最后合并后的特征矩阵的大小为： torch.Size([69, 1310])
# 最后合并后的距离矩阵的大小为： (69, 69)
# 最后合并后的标签的大小为： (69,)
# 1WTG_1_T_L
# 31
# 41
# all_target的大小为： 72
# tt的大小为： 72
# new_target的大小为： 72
# 最后合并后的特征矩阵的大小为： torch.Size([72, 1310])
# 最后合并后的距离矩阵的大小为： (72, 72)
# 最后合并后的标签的大小为： (72,)
# 1WUN_1_T_L
# 31
# 40
# all_target的大小为： 71
# tt的大小为： 71
# new_target的大小为： 71
# 最后合并后的特征矩阵的大小为： torch.Size([71, 1310])
# 最后合并后的距离矩阵的大小为： (71, 71)
# 最后合并后的标签的大小为： (71,)
# 1WV7_1_T_L
# 30
# 40
# all_target的大小为： 70
# tt的大小为： 70
# new_target的大小为： 70
# 最后合并后的特征矩阵的大小为： torch.Size([70, 1310])
# 最后合并后的距离矩阵的大小为： (70, 70)
# 最后合并后的标签的大小为： (70,)
# 1XWD_1_B_A
# 51
# 52
# all_target的大小为： 103
# tt的大小为： 103
# new_target的大小为： 103
# 最后合并后的特征矩阵的大小为： torch.Size([103, 1310])
# 最后合并后的距离矩阵的大小为： (103, 103)
# 最后合并后的标签的大小为： (103,)
# 1YF8_1_A_B
# 35
# 30
# all_target的大小为： 65
# tt的大小为： 65
# new_target的大小为： 65
# 最后合并后的特征矩阵的大小为： torch.Size([65, 1310])
# 最后合并后的距离矩阵的大小为： (65, 65)
# 最后合并后的标签的大小为： (65,)
# 1YJD_1_H_C
# 13
# 14
# all_target的大小为： 27
# tt的大小为： 27
# new_target的大小为： 27
# 最后合并后的特征矩阵的大小为： torch.Size([27, 1310])
# 最后合并后的距离矩阵的大小为： (27, 27)
# 最后合并后的标签的大小为： (27,)
# 1YPZ_1_F_E
# 48
# 46
# all_target的大小为： 94
# tt的大小为： 94
# new_target的大小为： 94
# 最后合并后的特征矩阵的大小为： torch.Size([94, 1310])
# 最后合并后的距离矩阵的大小为： (94, 94)
# 最后合并后的标签的大小为： (94,)
# 1YPZ_1_H_G
# 48
# 51
# all_target的大小为： 99
# tt的大小为： 99
# new_target的大小为： 99
# 最后合并后的特征矩阵的大小为： torch.Size([99, 1310])
# 最后合并后的距离矩阵的大小为： (99, 99)
# 最后合并后的标签的大小为： (99,)
# 2A2Q_1_T_L
# 31
# 37
# all_target的大小为： 68
# tt的大小为： 68
# new_target的大小为： 68
# 最后合并后的特征矩阵的大小为： torch.Size([68, 1310])
# 最后合并后的距离矩阵的大小为： (68, 68)
# 最后合并后的标签的大小为： (68,)
# 2AAI_1_A_B
# 36
# 51
# all_target的大小为： 87
# tt的大小为： 87
# new_target的大小为： 87
# 最后合并后的特征矩阵的大小为： torch.Size([87, 1310])
# 最后合并后的距离矩阵的大小为： (87, 87)
# 最后合并后的标签的大小为： (87,)
# 2AEP_1_L_A
# 11
# 10
# all_target的大小为： 21
# tt的大小为： 21
# new_target的大小为： 21
# 最后合并后的特征矩阵的大小为： torch.Size([21, 1310])
# 最后合并后的距离矩阵的大小为： (21, 21)
# 最后合并后的标签的大小为： (21,)
# 2AJF_1_E_A
# 25
# 22
# all_target的大小为： 47
# tt的大小为： 47
# new_target的大小为： 47
# 最后合并后的特征矩阵的大小为： torch.Size([47, 1310])
# 最后合并后的距离矩阵的大小为： (47, 47)
# 最后合并后的标签的大小为： (47,)
# 2B5I_1_C_B
# 23
# 27
# all_target的大小为： 50
# tt的大小为： 50
# new_target的大小为： 50
# 最后合并后的特征矩阵的大小为： torch.Size([50, 1310])
# 最后合并后的距离矩阵的大小为： (50, 50)
# 最后合并后的标签的大小为： (50,)
# 2B8O_1_T_L
# 29
# 36
# all_target的大小为： 65
# tt的大小为： 65
# new_target的大小为： 65
# 最后合并后的特征矩阵的大小为： torch.Size([65, 1310])
# 最后合并后的距离矩阵的大小为： (65, 65)
# 最后合并后的标签的大小为： (65,)
# 2BGN_1_E_B
# 20
# 25
# all_target的大小为： 45
# tt的大小为： 45
# new_target的大小为： 45
# 最后合并后的特征矩阵的大小为： torch.Size([45, 1310])
# 最后合并后的距离矩阵的大小为： (45, 45)
# 最后合并后的标签的大小为： (45,)
# 2BGN_1_F_A
# 24
# 27
# all_target的大小为： 51
# tt的大小为： 51
# new_target的大小为： 51
# 最后合并后的特征矩阵的大小为： torch.Size([51, 1310])
# 最后合并后的距离矩阵的大小为： (51, 51)
# 最后合并后的标签的大小为： (51,)
# 2C5D_1_C_A
# 28
# 27
# all_target的大小为： 55
# tt的大小为： 55
# new_target的大小为： 55
# 最后合并后的特征矩阵的大小为： torch.Size([55, 1310])
# 最后合并后的距离矩阵的大小为： (55, 55)
# 最后合并后的标签的大小为： (55,)
# 2C5D_1_D_B
# 29
# 28
# all_target的大小为： 57
# tt的大小为： 57
# new_target的大小为： 57
# 最后合并后的特征矩阵的大小为： torch.Size([57, 1310])
# 最后合并后的距离矩阵的大小为： (57, 57)
# 最后合并后的标签的大小为： (57,)
# 2DJF_1_B_A
# 22
# 21
# all_target的大小为： 43
# tt的大小为： 43
# new_target的大小为： 43
# 最后合并后的特征矩阵的大小为： torch.Size([43, 1310])
# 最后合并后的距离矩阵的大小为： (43, 43)
# 最后合并后的标签的大小为： (43,)
# 2DJF_1_C_A
# 8
# 9
# all_target的大小为： 17
# tt的大小为： 17
# new_target的大小为： 17
# 最后合并后的特征矩阵的大小为： torch.Size([17, 1310])
# 最后合并后的距离矩阵的大小为： (17, 17)
# 最后合并后的标签的大小为： (17,)
# 2DJG_1_C_A
# 8
# 9
# all_target的大小为： 17
# tt的大小为： 17
# new_target的大小为： 17
# 最后合并后的特征矩阵的大小为： torch.Size([17, 1310])
# 最后合并后的距离矩阵的大小为： (17, 17)
# 最后合并后的标签的大小为： (17,)
# 2E33_1_A_B
# 5
# 12
# all_target的大小为： 17
# tt的大小为： 17
# new_target的大小为： 17
# 最后合并后的特征矩阵的大小为： torch.Size([17, 1310])
# 最后合并后的距离矩阵的大小为： (17, 17)
# 最后合并后的标签的大小为： (17,)
# 2ERJ_1_C_B
# 22
# 27
# all_target的大小为： 49
# tt的大小为： 49
# new_target的大小为： 49
# 最后合并后的特征矩阵的大小为： torch.Size([49, 1310])
# 最后合并后的距离矩阵的大小为： (49, 49)
# 最后合并后的标签的大小为： (49,)
# 2FBJ_1_L_H
# 51
# 49
# all_target的大小为： 100
# tt的大小为： 100
# new_target的大小为： 100
# 最后合并后的特征矩阵的大小为： torch.Size([100, 1310])
# 最后合并后的距离矩阵的大小为： (100, 100)
# 最后合并后的标签的大小为： (100,)
# 2G5B_1_A_B
# 50
# 49
# all_target的大小为： 99
# tt的大小为： 99
# new_target的大小为： 99
# 最后合并后的特征矩阵的大小为： torch.Size([99, 1310])
# 最后合并后的距离矩阵的大小为： (99, 99)
# 最后合并后的标签的大小为： (99,)
# 2I07_1_A_B
# 115
# 122
# all_target的大小为： 237
# tt的大小为： 237
# new_target的大小为： 237
# 最后合并后的特征矩阵的大小为： torch.Size([237, 1310])
# 最后合并后的距离矩阵的大小为： (237, 237)
# 最后合并后的标签的大小为： (237,)
# 2MLL_1_A_B
# 32
# 31
# all_target的大小为： 63
# tt的大小为： 63
# new_target的大小为： 63
# 最后合并后的特征矩阵的大小为： torch.Size([63, 1310])
# 最后合并后的距离矩阵的大小为： (63, 63)
# 最后合并后的标签的大小为： (63,)
# 2NY7_1_H_G
# 31
# 25
# all_target的大小为： 56
# tt的大小为： 56
# new_target的大小为： 56
# 最后合并后的特征矩阵的大小为： torch.Size([56, 1310])
# 最后合并后的距离矩阵的大小为： (56, 56)
# 最后合并后的标签的大小为： (56,)
# 2PUQ_1_T_L
# 20
# 24
# all_target的大小为： 44
# tt的大小为： 44
# new_target的大小为： 44
# 最后合并后的特征矩阵的大小为： torch.Size([44, 1310])
# 最后合并后的距离矩阵的大小为： (44, 44)
# 最后合并后的标签的大小为： (44,)
# 2QC1_1_A_B
# 19
# 22
# all_target的大小为： 41
# tt的大小为： 41
# new_target的大小为： 41
# 最后合并后的特征矩阵的大小为： torch.Size([41, 1310])
# 最后合并后的距离矩阵的大小为： (41, 41)
# 最后合并后的标签的大小为： (41,)
# 2R9K_1_A_B
# 38
# 40
# all_target的大小为： 77
# tt的大小为： 77
# new_target的大小为： 77
# 最后合并后的特征矩阵的大小为： torch.Size([77, 1310])
# 最后合并后的距离矩阵的大小为： (77, 77)
# 最后合并后的标签的大小为： (77,)
# 2RG9_1_A_B
# 39
# 43
# all_target的大小为： 82
# tt的大小为： 82
# new_target的大小为： 82
# 最后合并后的特征矩阵的大小为： torch.Size([82, 1310])
# 最后合并后的距离矩阵的大小为： (82, 82)
# 最后合并后的标签的大小为： (82,)
# 2SEB_1_B_A
# 66
# 54
# all_target的大小为： 120
# tt的大小为： 120
# new_target的大小为： 120
# 最后合并后的特征矩阵的大小为： torch.Size([120, 1310])
# 最后合并后的距离矩阵的大小为： (120, 120)
# 最后合并后的标签的大小为： (120,)
# 2VC2_1_A_B
# 41
# 47
# all_target的大小为： 88
# tt的大小为： 88
# new_target的大小为： 88
# 最后合并后的特征矩阵的大小为： torch.Size([88, 1310])
# 最后合并后的距离矩阵的大小为： (88, 88)
# 最后合并后的标签的大小为： (88,)
# 2VDK_1_A_B
# 40
# 46
# all_target的大小为： 86
# tt的大小为： 86
# new_target的大小为： 86
# 最后合并后的特征矩阵的大小为： torch.Size([86, 1310])
# 最后合并后的距离矩阵的大小为： (86, 86)
# 最后合并后的标签的大小为： (86,)
# 2VDL_1_A_B
# 38
# 47
# all_target的大小为： 85
# tt的大小为： 85
# new_target的大小为： 85
# 最后合并后的特征矩阵的大小为： torch.Size([85, 1310])
# 最后合并后的距离矩阵的大小为： (85, 85)
# 最后合并后的标签的大小为： (85,)
# 2VDM_1_A_B
# 39
# 46
# all_target的大小为： 85
# tt的大小为： 85
# new_target的大小为： 85
# 最后合并后的特征矩阵的大小为： torch.Size([85, 1310])
# 最后合并后的距离矩阵的大小为： (85, 85)
# 最后合并后的标签的大小为： (85,)
# 2VDN_1_A_B
# 38
# 45
# all_target的大小为： 83
# tt的大小为： 83
# new_target的大小为： 83
# 最后合并后的特征矩阵的大小为： torch.Size([83, 1310])
# 最后合并后的距离矩阵的大小为： (83, 83)
# 最后合并后的标签的大小为： (83,)
# 2VDO_1_A_B
# 37
# 47
# all_target的大小为： 84
# tt的大小为： 84
# new_target的大小为： 84
# 最后合并后的特征矩阵的大小为： torch.Size([84, 1310])
# 最后合并后的距离矩阵的大小为： (84, 84)
# 最后合并后的标签的大小为： (84,)
# 2VDP_1_A_B
# 37
# 45
# all_target的大小为： 82
# tt的大小为： 82
# new_target的大小为： 82
# 最后合并后的特征矩阵的大小为： torch.Size([82, 1310])
# 最后合并后的距离矩阵的大小为： (82, 82)
# 最后合并后的标签的大小为： (82,)
# 2VDQ_1_A_B
# 37
# 46
# all_target的大小为： 83
# tt的大小为： 83
# new_target的大小为： 83
# 最后合并后的特征矩阵的大小为： torch.Size([83, 1310])
# 最后合并后的距离矩阵的大小为： (83, 83)
# 最后合并后的标签的大小为： (83,)
# 2VDR_1_A_B
# 37
# 45
# all_target的大小为： 82
# tt的大小为： 82
# new_target的大小为： 82
# 最后合并后的特征矩阵的大小为： torch.Size([82, 1310])
# 最后合并后的距离矩阵的大小为： (82, 82)
# 最后合并后的标签的大小为： (82,)
# 2WII_1_A_B
# 111
# 118
# all_target的大小为： 229
# tt的大小为： 229
# new_target的大小为： 229
# 最后合并后的特征矩阵的大小为： torch.Size([229, 1310])
# 最后合并后的距离矩阵的大小为： (229, 229)
# 最后合并后的标签的大小为： (229,)
# 2WIN_1_A_B
# 111
# 118
# all_target的大小为： 229
# tt的大小为： 229
# new_target的大小为： 229
# 最后合并后的特征矩阵的大小为： torch.Size([229, 1310])
# 最后合并后的距离矩阵的大小为： (229, 229)
# 最后合并后的标签的大小为： (229,)
# 2WIN_1_G_H
# 104
# 112
# all_target的大小为： 216
# tt的大小为： 216
# new_target的大小为： 216
# 最后合并后的特征矩阵的大小为： torch.Size([216, 1310])
# 最后合并后的距离矩阵的大小为： (216, 216)
# 最后合并后的标签的大小为： (216,)
# 2Y7Q_1_A_B
# 14
# 8
# all_target的大小为： 22
# tt的大小为： 22
# new_target的大小为： 22
# 最后合并后的特征矩阵的大小为： torch.Size([22, 1310])
# 最后合并后的距离矩阵的大小为： (22, 22)
# 最后合并后的标签的大小为： (22,)
# 2YDQ_1_A_T
# 6
# 20
# all_target的大小为： 26
# tt的大小为： 26
# new_target的大小为： 26
# 最后合并后的特征矩阵的大小为： torch.Size([26, 1310])
# 最后合并后的距离矩阵的大小为： (26, 26)
# 最后合并后的标签的大小为： (26,)
# 2YDR_1_A_P
# 6
# 20
# all_target的大小为： 26
# tt的大小为： 26
# new_target的大小为： 26
# 最后合并后的特征矩阵的大小为： torch.Size([26, 1310])
# 最后合并后的距离矩阵的大小为： (26, 26)
# 最后合并后的标签的大小为： (26,)
# 2YDS_1_A_T
# 5
# 18
# all_target的大小为： 23
# tt的大小为： 23
# new_target的大小为： 23
# 最后合并后的特征矩阵的大小为： torch.Size([23, 1310])
# 最后合并后的距离矩阵的大小为： (23, 23)
# 最后合并后的标签的大小为： (23,)
# 2ZP0_1_T_L
# 29
# 36
# all_target的大小为： 65
# tt的大小为： 65
# new_target的大小为： 65
# 最后合并后的特征矩阵的大小为： torch.Size([65, 1310])
# 最后合并后的距离矩阵的大小为： (65, 65)
# 最后合并后的标签的大小为： (65,)
# 2ZR1_1_A_B
# 45
# 51
# all_target的大小为： 96
# tt的大小为： 96
# new_target的大小为： 96
# 最后合并后的特征矩阵的大小为： torch.Size([96, 1310])
# 最后合并后的距离矩阵的大小为： (96, 96)
# 最后合并后的标签的大小为： (96,)
# 2ZWL_1_T_L
# 29
# 41
# all_target的大小为： 70
# tt的大小为： 70
# new_target的大小为： 70
# 最后合并后的特征矩阵的大小为： torch.Size([70, 1310])
# 最后合并后的距离矩阵的大小为： (70, 70)
# 最后合并后的标签的大小为： (70,)
# 2ZZU_1_T_L
# 31
# 39
# all_target的大小为： 70
# tt的大小为： 70
# new_target的大小为： 70
# 最后合并后的特征矩阵的大小为： torch.Size([70, 1310])
# 最后合并后的距离矩阵的大小为： (70, 70)
# 最后合并后的标签的大小为： (70,)
# 3AY4_1_A_C
# 15
# 19
# all_target的大小为： 34
# tt的大小为： 34
# new_target的大小为： 34
# 最后合并后的特征矩阵的大小为： torch.Size([34, 1310])
# 最后合并后的距离矩阵的大小为： (34, 34)
# 最后合并后的标签的大小为： (34,)
# 3AY4_1_C_A
# 18
# 14
# all_target的大小为： 32
# tt的大小为： 32
# new_target的大小为： 32
# 最后合并后的特征矩阵的大小为： torch.Size([32, 1310])
# 最后合并后的距离矩阵的大小为： (32, 32)
# 最后合并后的标签的大小为： (32,)
# 3B2D_1_C_A
# 31
# 34
# all_target的大小为： 65
# tt的大小为： 65
# new_target的大小为： 65
# 最后合并后的特征矩阵的大小为： torch.Size([65, 1310])
# 最后合并后的距离矩阵的大小为： (65, 65)
# 最后合并后的标签的大小为： (65,)
# 3B2D_1_D_B
# 29
# 33
# all_target的大小为： 62
# tt的大小为： 62
# new_target的大小为： 62
# 最后合并后的特征矩阵的大小为： torch.Size([62, 1310])
# 最后合并后的距离矩阵的大小为： (62, 62)
# 最后合并后的标签的大小为： (62,)
# 3B9F_1_I_H
# 43
# 17
# all_target的大小为： 56
# tt的大小为： 56
# new_target的大小为： 56
# 最后合并后的特征矩阵的大小为： torch.Size([56, 1310])
# 最后合并后的距离矩阵的大小为： (56, 56)
# 最后合并后的标签的大小为： (56,)
# 3BPO_1_A_B
# 18
# 15
# all_target的大小为： 33
# tt的大小为： 33
# new_target的大小为： 33
# 最后合并后的特征矩阵的大小为： torch.Size([33, 1310])
# 最后合并后的距离矩阵的大小为： (33, 33)
# 最后合并后的标签的大小为： (33,)
# 3C6E_1_C_A
# 23
# 26
# all_target的大小为： 49
# tt的大小为： 49
# new_target的大小为： 49
# 最后合并后的特征矩阵的大小为： torch.Size([49, 1310])
# 最后合并后的距离矩阵的大小为： (49, 49)
# 最后合并后的标签的大小为： (49,)
# 3CUP_1_B_A
# 80
# 70
# all_target的大小为： 150
# tt的大小为： 150
# new_target的大小为： 150
# 最后合并后的特征矩阵的大小为： torch.Size([150, 1310])
# 最后合并后的距离矩阵的大小为： (150, 150)
# 最后合并后的标签的大小为： (150,)
# 3D7W_1_A_B
# 39
# 41
# all_target的大小为： 80
# tt的大小为： 80
# new_target的大小为： 80
# 最后合并后的特征矩阵的大小为： torch.Size([80, 1310])
# 最后合并后的距离矩阵的大小为： (80, 80)
# 最后合并后的标签的大小为： (80,)
# 3E6P_1_L_H
# 83
# 62
# all_target的大小为： 145
# tt的大小为： 145
# new_target的大小为： 145
# 最后合并后的特征矩阵的大小为： torch.Size([145, 1310])
# 最后合并后的距离矩阵的大小为： (145, 145)
# 最后合并后的标签的大小为： (145,)
# 3F8U_1_A_B
# 34
# 29
# all_target的大小为： 63
# tt的大小为： 63
# new_target的大小为： 63
# 最后合并后的特征矩阵的大小为： torch.Size([63, 1310])
# 最后合并后的距离矩阵的大小为： (63, 63)
# 最后合并后的标签的大小为： (63,)
# 3FCS_1_A_B
# 83
# 91
# all_target的大小为： 173
# tt的大小为： 173
# new_target的大小为： 173
# 最后合并后的特征矩阵的大小为： torch.Size([173, 1310])
# 最后合并后的距离矩阵的大小为： (173, 173)
# 最后合并后的标签的大小为： (173,)
# 3FCU_1_A_B
# 38
# 44
# all_target的大小为： 82
# tt的大小为： 82
# new_target的大小为： 82
# 最后合并后的特征矩阵的大小为： torch.Size([82, 1310])
# 最后合并后的距离矩阵的大小为： (82, 82)
# 最后合并后的标签的大小为： (82,)
# 3IDX_1_H_G
# 22
# 20
# all_target的大小为： 42
# tt的大小为： 42
# new_target的大小为： 42
# 最后合并后的特征矩阵的大小为： torch.Size([42, 1310])
# 最后合并后的距离矩阵的大小为： (42, 42)
# 最后合并后的标签的大小为： (42,)
# 3IDY_1_B_A
# 23
# 20
# all_target的大小为： 43
# tt的大小为： 43
# new_target的大小为： 43
# 最后合并后的特征矩阵的大小为： torch.Size([43, 1310])
# 最后合并后的距离矩阵的大小为： (43, 43)
# 最后合并后的标签的大小为： (43,)
# 3IDY_1_H_G
# 20
# 20
# all_target的大小为： 40
# tt的大小为： 40
# new_target的大小为： 40
# 最后合并后的特征矩阵的大小为： torch.Size([40, 1310])
# 最后合并后的距离矩阵的大小为： (40, 40)
# 最后合并后的标签的大小为： (40,)
# 3IET_1_A_X
# 6
# 10
# all_target的大小为： 16
# tt的大小为： 16
# new_target的大小为： 16
# 最后合并后的特征矩阵的大小为： torch.Size([16, 1310])
# 最后合并后的距离矩阵的大小为： (16, 16)
# 最后合并后的标签的大小为： (16,)
# 3IET_1_B_X
# 6
# 9
# all_target的大小为： 15
# tt的大小为： 15
# new_target的大小为： 15
# 最后合并后的特征矩阵的大小为： torch.Size([15, 1310])
# 最后合并后的距离矩阵的大小为： (15, 15)
# 最后合并后的标签的大小为： (15,)
# 3IET_1_C_Q
# 4
# 8
# all_target的大小为： 12
# tt的大小为： 12
# new_target的大小为： 12
# 最后合并后的特征矩阵的大小为： torch.Size([12, 1310])
# 最后合并后的距离矩阵的大小为： (12, 12)
# 最后合并后的标签的大小为： (12,)
# 3IET_1_D_Q
# 5
# 9
# all_target的大小为： 14
# tt的大小为： 14
# new_target的大小为： 14
# 最后合并后的特征矩阵的大小为： torch.Size([14, 1310])
# 最后合并后的距离矩阵的大小为： (14, 14)
# 最后合并后的标签的大小为： (14,)
# 3IJE_1_A_B
# 85
# 92
# all_target的大小为： 177
# tt的大小为： 177
# new_target的大小为： 177
# 最后合并后的特征矩阵的大小为： torch.Size([177, 1310])
# 最后合并后的距离矩阵的大小为： (177, 177)
# 最后合并后的标签的大小为： (177,)
# 3IU3_1_B_K
# 12
# 8
# all_target的大小为： 20
# tt的大小为： 20
# new_target的大小为： 20
# 最后合并后的特征矩阵的大小为： torch.Size([20, 1310])
# 最后合并后的距离矩阵的大小为： (20, 20)
# 最后合并后的标签的大小为： (20,)
# 3K6S_1_B_A
# 93
# 89
# all_target的大小为： 182
# tt的大小为： 182
# new_target的大小为： 182
# 最后合并后的特征矩阵的大小为： torch.Size([182, 1310])
# 最后合并后的距离矩阵的大小为： (182, 182)
# 最后合并后的标签的大小为： (182,)
# 3K71_1_B_A
# 82
# 80
# all_target的大小为： 162
# tt的大小为： 162
# new_target的大小为： 162
# 最后合并后的特征矩阵的大小为： torch.Size([162, 1310])
# 最后合并后的距离矩阵的大小为： (162, 162)
# 最后合并后的标签的大小为： (162,)
# 3K72_1_B_A
# 84
# 83
# all_target的大小为： 167
# tt的大小为： 167
# new_target的大小为： 167
# 最后合并后的特征矩阵的大小为： torch.Size([167, 1310])
# 最后合并后的距离矩阵的大小为： (167, 167)
# 最后合并后的标签的大小为： (167,)
# 3KQ4_1_B_A
# 27
# 26
# all_target的大小为： 53
# tt的大小为： 53
# new_target的大小为： 53
# 最后合并后的特征矩阵的大小为： torch.Size([53, 1310])
# 最后合并后的距离矩阵的大小为： (53, 53)
# 最后合并后的标签的大小为： (53,)
# 3LIZ_1_H_A
# 21
# 21
# all_target的大小为： 42
# tt的大小为： 42
# new_target的大小为： 42
# 最后合并后的特征矩阵的大小为： torch.Size([42, 1310])
# 最后合并后的距离矩阵的大小为： (42, 42)
# 最后合并后的标签的大小为： (42,)
# 3N41_1_F_B
# 57
# 51
# all_target的大小为： 108
# tt的大小为： 108
# new_target的大小为： 108
# 最后合并后的特征矩阵的大小为： torch.Size([108, 1310])
# 最后合并后的距离矩阵的大小为： (108, 108)
# 最后合并后的标签的大小为： (108,)
# 3N42_1_F_B
# 67
# 59
# all_target的大小为： 126
# tt的大小为： 126
# new_target的大小为： 126
# 最后合并后的特征矩阵的大小为： torch.Size([126, 1310])
# 最后合并后的距离矩阵的大小为： (126, 126)
# 最后合并后的标签的大小为： (126,)
# 3N43_1_F_B
# 70
# 61
# all_target的大小为： 131
# tt的大小为： 131
# new_target的大小为： 131
# 最后合并后的特征矩阵的大小为： torch.Size([131, 1310])
# 最后合并后的距离矩阵的大小为： (131, 131)
# 最后合并后的标签的大小为： (131,)
# 3NGB_1_H_G
# 29
# 22
# all_target的大小为： 51
# tt的大小为： 51
# new_target的大小为： 51
# 最后合并后的特征矩阵的大小为： torch.Size([51, 1310])
# 最后合并后的距离矩阵的大小为： (51, 51)
# 最后合并后的标签的大小为： (51,)
# 3NGB_1_L_G
# 8
# 8
# all_target的大小为： 16
# tt的大小为： 16
# new_target的大小为： 16
# 最后合并后的特征矩阵的大小为： torch.Size([16, 1310])
# 最后合并后的距离矩阵的大小为： (16, 16)
# 最后合并后的标签的大小为： (16,)
# 3NID_1_A_B
# 39
# 48
# all_target的大小为： 87
# tt的大小为： 87
# new_target的大小为： 87
# 最后合并后的特征矩阵的大小为： torch.Size([87, 1310])
# 最后合并后的距离矩阵的大小为： (87, 87)
# 最后合并后的标签的大小为： (87,)
# 3NIF_1_A_B
# 40
# 47
# all_target的大小为： 87
# tt的大小为： 87
# new_target的大小为： 87
# 最后合并后的特征矩阵的大小为： torch.Size([87, 1310])
# 最后合并后的距离矩阵的大小为： (87, 87)
# 最后合并后的标签的大小为： (87,)
# 3NIG_1_A_B
# 42
# 49
# all_target的大小为： 91
# tt的大小为： 91
# new_target的大小为： 91
# 最后合并后的特征矩阵的大小为： torch.Size([91, 1310])
# 最后合并后的距离矩阵的大小为： (91, 91)
# 最后合并后的标签的大小为： (91,)
# 3O5W_1_A_B
# 39
# 40
# all_target的大小为： 79
# tt的大小为： 79
# new_target的大小为： 79
# 最后合并后的特征矩阵的大小为： torch.Size([79, 1310])
# 最后合并后的距离矩阵的大小为： (79, 79)
# 最后合并后的标签的大小为： (79,)
# 3OJA_1_A_B
# 107
# 101
# all_target的大小为： 208
# tt的大小为： 208
# new_target的大小为： 208
# 最后合并后的特征矩阵的大小为： torch.Size([208, 1310])
# 最后合并后的距离矩阵的大小为： (208, 208)
# 最后合并后的标签的大小为： (208,)
# 3PV6_1_B_A
# 18
# 16
# all_target的大小为： 34
# tt的大小为： 34
# new_target的大小为： 34
# 最后合并后的特征矩阵的大小为： torch.Size([34, 1310])
# 最后合并后的距离矩阵的大小为： (34, 34)
# 最后合并后的标签的大小为： (34,)
# 3QB7_1_A_D
# 15
# 13
# all_target的大小为： 28
# tt的大小为： 28
# new_target的大小为： 28
# 最后合并后的特征矩阵的大小为： torch.Size([28, 1310])
# 最后合并后的距离矩阵的大小为： (28, 28)
# 最后合并后的标签的大小为： (28,)
# 3QUM_1_B_P
# 14
# 19
# all_target的大小为： 33
# tt的大小为： 33
# new_target的大小为： 33
# 最后合并后的特征矩阵的大小为： torch.Size([33, 1310])
# 最后合并后的距离矩阵的大小为： (33, 33)
# 最后合并后的标签的大小为： (33,)
# 3QUM_1_H_P
# 27
# 20
# all_target的大小为： 47
# tt的大小为： 47
# new_target的大小为： 47
# 最后合并后的特征矩阵的大小为： torch.Size([47, 1310])
# 最后合并后的距离矩阵的大小为： (47, 47)
# 最后合并后的标签的大小为： (47,)
# 3RG1_1_C_A
# 31
# 33
# all_target的大小为： 64
# tt的大小为： 64
# new_target的大小为： 64
# 最后合并后的特征矩阵的大小为： torch.Size([64, 1310])
# 最后合并后的距离矩阵的大小为： (64, 64)
# 最后合并后的标签的大小为： (64,)
# 3RG1_1_D_B
# 31
# 33
# all_target的大小为： 64
# tt的大小为： 64
# new_target的大小为： 64
# 最后合并后的特征矩阵的大小为： torch.Size([64, 1310])
# 最后合并后的距离矩阵的大小为： (64, 64)
# 最后合并后的标签的大小为： (64,)
# 3RTI_1_A_B
# 36
# 47
# all_target的大小为： 83
# tt的大小为： 83
# new_target的大小为： 83
# 最后合并后的特征矩阵的大小为： torch.Size([83, 1310])
# 最后合并后的距离矩阵的大小为： (83, 83)
# 最后合并后的标签的大小为： (83,)
# 3RTJ_1_A_B
# 35
# 46
# all_target的大小为： 81
# tt的大小为： 81
# new_target的大小为： 81
# 最后合并后的特征矩阵的大小为： torch.Size([81, 1310])
# 最后合并后的距离矩阵的大小为： (81, 81)
# 最后合并后的标签的大小为： (81,)
# 3RY6_1_C_B
# 13
# 12
# all_target的大小为： 25
# tt的大小为： 25
# new_target的大小为： 25
# 最后合并后的特征矩阵的大小为： torch.Size([25, 1310])
# 最后合并后的距离矩阵的大小为： (25, 25)
# 最后合并后的标签的大小为： (25,)
# 3S35_1_L_X
# 10
# 15
# all_target的大小为： 25
# tt的大小为： 25
# new_target的大小为： 25
# 最后合并后的特征矩阵的大小为： torch.Size([25, 1310])
# 最后合并后的距离矩阵的大小为： (25, 25)
# 最后合并后的标签的大小为： (25,)
# 3SC2_1_A_B
# 86
# 115
# all_target的大小为： 201
# tt的大小为： 201
# new_target的大小为： 201
# 最后合并后的特征矩阵的大小为： torch.Size([201, 1310])
# 最后合并后的距离矩阵的大小为： (201, 201)
# 最后合并后的标签的大小为： (201,)
# 3SC2_1_B_A
# 116
# 87
# all_target的大小为： 203
# tt的大小为： 203
# new_target的大小为： 203
# 最后合并后的特征矩阵的大小为： torch.Size([203, 1310])
# 最后合并后的距离矩阵的大小为： (203, 203)
# 最后合并后的标签的大小为： (203,)
# 3SDY_1_L_B
# 8
# 6
# all_target的大小为： 14
# tt的大小为： 14
# new_target的大小为： 14
# 最后合并后的特征矩阵的大小为： torch.Size([14, 1310])
# 最后合并后的距离矩阵的大小为： (14, 14)
# 最后合并后的标签的大小为： (14,)
# 3SE8_1_L_G
# 9
# 9
# all_target的大小为： 18
# tt的大小为： 18
# new_target的大小为： 18
# 最后合并后的特征矩阵的大小为： torch.Size([18, 1310])
# 最后合并后的距离矩阵的大小为： (18, 18)
# 最后合并后的标签的大小为： (18,)
# 3SE9_1_H_G
# 24
# 25
# all_target的大小为： 49
# tt的大小为： 49
# new_target的大小为： 49
# 最后合并后的特征矩阵的大小为： torch.Size([49, 1310])
# 最后合并后的距离矩阵的大小为： (49, 49)
# 最后合并后的标签的大小为： (49,)
# 3SE9_1_L_G
# 8
# 8
# all_target的大小为： 16
# tt的大小为： 16
# new_target的大小为： 16
# 最后合并后的特征矩阵的大小为： torch.Size([16, 1310])
# 最后合并后的距离矩阵的大小为： (16, 16)
# 最后合并后的标签的大小为： (16,)
# 3SGJ_1_A_C
# 13
# 17
# all_target的大小为： 30
# tt的大小为： 30
# new_target的大小为： 30
# 最后合并后的特征矩阵的大小为： torch.Size([30, 1310])
# 最后合并后的距离矩阵的大小为： (30, 30)
# 最后合并后的标签的大小为： (30,)
# 3SGJ_1_C_A
# 17
# 12
# all_target的大小为： 29
# tt的大小为： 29
# new_target的大小为： 29
# 最后合并后的特征矩阵的大小为： torch.Size([29, 1310])
# 最后合并后的距离矩阵的大小为： (29, 29)
# 最后合并后的标签的大小为： (29,)
# 3SGK_1_A_C
# 14
# 15
# all_target的大小为： 29
# tt的大小为： 29
# new_target的大小为： 29
# 最后合并后的特征矩阵的大小为： torch.Size([29, 1310])
# 最后合并后的距离矩阵的大小为： (29, 29)
# 最后合并后的标签的大小为： (29,)
# 3SGK_1_C_A
# 13
# 13
# all_target的大小为： 26
# tt的大小为： 26
# new_target的大小为： 26
# 最后合并后的特征矩阵的大小为： torch.Size([26, 1310])
# 最后合并后的距离矩阵的大小为： (26, 26)
# 最后合并后的标签的大小为： (26,)
# 3T3M_1_A_B
# 40
# 47
# all_target的大小为： 87
# tt的大小为： 87
# new_target的大小为： 87
# 最后合并后的特征矩阵的大小为： torch.Size([87, 1310])
# 最后合并后的距离矩阵的大小为： (87, 87)
# 最后合并后的标签的大小为： (87,)
# 3T3P_1_A_B
# 38
# 47
# all_target的大小为： 85
# tt的大小为： 85
# new_target的大小为： 85
# 最后合并后的特征矩阵的大小为： torch.Size([85, 1310])
# 最后合并后的距离矩阵的大小为： (85, 85)
# 最后合并后的标签的大小为： (85,)
# 3T6Q_1_C_A
# 32
# 36
# all_target的大小为： 67
# tt的大小为： 67
# new_target的大小为： 67
# 最后合并后的特征矩阵的大小为： torch.Size([67, 1310])
# 最后合并后的距离矩阵的大小为： (67, 67)
# 最后合并后的标签的大小为： (67,)
# 3T6Q_1_D_B
# 32
# 34
# all_target的大小为： 65
# tt的大小为： 65
# new_target的大小为： 65
# 最后合并后的特征矩阵的大小为： torch.Size([65, 1310])
# 最后合并后的距离矩阵的大小为： (65, 65)
# 最后合并后的标签的大小为： (65,)
# 3TH2_1_T_L
# 29
# 39
# all_target的大小为： 68
# tt的大小为： 68
# new_target的大小为： 68
# 最后合并后的特征矩阵的大小为： torch.Size([68, 1310])
# 最后合并后的距离矩阵的大小为： (68, 68)
# 最后合并后的标签的大小为： (68,)
# 3TH3_1_T_L
# 21
# 26
# all_target的大小为： 47
# tt的大小为： 47
# new_target的大小为： 47
# 最后合并后的特征矩阵的大小为： torch.Size([47, 1310])
# 最后合并后的距离矩阵的大小为： (47, 47)
# 最后合并后的标签的大小为： (47,)
# 3TH4_1_T_L
# 30
# 36
# all_target的大小为： 66
# tt的大小为： 66
# new_target的大小为： 66
# 最后合并后的特征矩阵的大小为： torch.Size([66, 1310])
# 最后合并后的距离矩阵的大小为： (66, 66)
# 最后合并后的标签的大小为： (66,)
# 3TYG_1_H_A
# 10
# 30
# all_target的大小为： 40
# tt的大小为： 40
# new_target的大小为： 40
# 最后合并后的特征矩阵的大小为： torch.Size([40, 1310])
# 最后合并后的距离矩阵的大小为： (40, 40)
# 最后合并后的标签的大小为： (40,)
# 3U2S_1_H_G
# 13
# 16
# all_target的大小为： 29
# tt的大小为： 29
# new_target的大小为： 29
# 最后合并后的特征矩阵的大小为： torch.Size([29, 1310])
# 最后合并后的距离矩阵的大小为： (29, 29)
# 最后合并后的标签的大小为： (29,)
# 3U4E_1_H_G
# 17
# 21
# all_target的大小为： 38
# tt的大小为： 38
# new_target的大小为： 38
# 最后合并后的特征矩阵的大小为： torch.Size([38, 1310])
# 最后合并后的距离矩阵的大小为： (38, 38)
# 最后合并后的标签的大小为： (38,)
# 3UJI_1_L_H
# 47
# 47
# all_target的大小为： 94
# tt的大小为： 94
# new_target的大小为： 94
# 最后合并后的特征矩阵的大小为： torch.Size([94, 1310])
# 最后合并后的距离矩阵的大小为： (94, 94)
# 最后合并后的标签的大小为： (94,)
# 3ULU_1_E_A
# 14
# 12
# all_target的大小为： 26
# tt的大小为： 26
# new_target的大小为： 26
# 最后合并后的特征矩阵的大小为： torch.Size([26, 1310])
# 最后合并后的距离矩阵的大小为： (26, 26)
# 最后合并后的标签的大小为： (26,)
# 3ULU_1_L_A
# 13
# 10
# all_target的大小为： 23
# tt的大小为： 23
# new_target的大小为： 23
# 最后合并后的特征矩阵的大小为： torch.Size([23, 1310])
# 最后合并后的距离矩阵的大小为： (23, 23)
# 最后合并后的标签的大小为： (23,)
# 3ULV_1_E_A
# 12
# 11
# all_target的大小为： 23
# tt的大小为： 23
# new_target的大小为： 23
# 最后合并后的特征矩阵的大小为： torch.Size([23, 1310])
# 最后合并后的距离矩阵的大小为： (23, 23)
# 最后合并后的标签的大小为： (23,)
# 3ULV_1_L_A
# 15
# 11
# all_target的大小为： 26
# tt的大小为： 26
# new_target的大小为： 26
# 最后合并后的特征矩阵的大小为： torch.Size([26, 1310])
# 最后合并后的距离矩阵的大小为： (26, 26)
# 最后合并后的标签的大小为： (26,)
# 3V8X_1_A_B
# 58
# 98
# all_target的大小为： 155
# tt的大小为： 155
# new_target的大小为： 155
# 最后合并后的特征矩阵的大小为： torch.Size([155, 1310])
# 最后合并后的距离矩阵的大小为： (155, 155)
# 最后合并后的标签的大小为： (155,)
# 3W11_1_C_E
# 17
# 14
# all_target的大小为： 31
# tt的大小为： 31
# new_target的大小为： 31
# 最后合并后的特征矩阵的大小为： torch.Size([31, 1310])
# 最后合并后的距离矩阵的大小为： (31, 31)
# 最后合并后的标签的大小为： (31,)
# 3WCT_1_A_D
# 30
# 29
# all_target的大小为： 59
# tt的大小为： 59
# new_target的大小为： 59
# 最后合并后的特征矩阵的大小为： torch.Size([59, 1310])
# 最后合并后的距离矩阵的大小为： (59, 59)
# 最后合并后的标签的大小为： (59,)
# 3WCT_1_B_D
# 15
# 14
# all_target的大小为： 29
# tt的大小为： 29
# new_target的大小为： 29
# 最后合并后的特征矩阵的大小为： torch.Size([29, 1310])
# 最后合并后的距离矩阵的大小为： (29, 29)
# 最后合并后的标签的大小为： (29,)
# 3WCT_1_C_D
# 3
# 4
# all_target的大小为： 7
# tt的大小为： 7
# new_target的大小为： 7
# 最后合并后的特征矩阵的大小为： torch.Size([7, 1310])
# 最后合并后的距离矩阵的大小为： (7, 7)
# 最后合并后的标签的大小为： (7,)
# 3WCT_1_E_H
# 29
# 28
# all_target的大小为： 57
# tt的大小为： 57
# new_target的大小为： 57
# 最后合并后的特征矩阵的大小为： torch.Size([57, 1310])
# 最后合并后的距离矩阵的大小为： (57, 57)
# 最后合并后的标签的大小为： (57,)
# 3WCU_1_A_D
# 31
# 28
# all_target的大小为： 59
# tt的大小为： 59
# new_target的大小为： 59
# 最后合并后的特征矩阵的大小为： torch.Size([59, 1310])
# 最后合并后的距离矩阵的大小为： (59, 59)
# 最后合并后的标签的大小为： (59,)
# 3WCU_1_E_H
# 31
# 28
# all_target的大小为： 59
# tt的大小为： 59
# new_target的大小为： 59
# 最后合并后的特征矩阵的大小为： torch.Size([59, 1310])
# 最后合并后的距离矩阵的大小为： (59, 59)
# 最后合并后的标签的大小为： (59,)
# 3WCV_1_A_D
# 29
# 29
# all_target的大小为： 58
# tt的大小为： 58
# new_target的大小为： 58
# 最后合并后的特征矩阵的大小为： torch.Size([58, 1310])
# 最后合并后的距离矩阵的大小为： (58, 58)
# 最后合并后的标签的大小为： (58,)
# 3WCV_1_B_D
# 15
# 14
# all_target的大小为： 29
# tt的大小为： 29
# new_target的大小为： 29
# 最后合并后的特征矩阵的大小为： torch.Size([29, 1310])
# 最后合并后的距离矩阵的大小为： (29, 29)
# 最后合并后的标签的大小为： (29,)
# 3WCV_1_E_H
# 29
# 28
# all_target的大小为： 57
# tt的大小为： 57
# new_target的大小为： 57
# 最后合并后的特征矩阵的大小为： torch.Size([57, 1310])
# 最后合并后的距离矩阵的大小为： (57, 57)
# 最后合并后的标签的大小为： (57,)
# 3WCW_1_A_D
# 29
# 29
# all_target的大小为： 58
# tt的大小为： 58
# new_target的大小为： 58
# 最后合并后的特征矩阵的大小为： torch.Size([58, 1310])
# 最后合并后的距离矩阵的大小为： (58, 58)
# 最后合并后的标签的大小为： (58,)
# 3WCW_1_E_H
# 29
# 28
# all_target的大小为： 57
# tt的大小为： 57
# new_target的大小为： 57
# 最后合并后的特征矩阵的大小为： torch.Size([57, 1310])
# 最后合并后的距离矩阵的大小为： (57, 57)
# 最后合并后的标签的大小为： (57,)
# 3WJJ_1_C_B
# 12
# 8
# all_target的大小为： 20
# tt的大小为： 20
# new_target的大小为： 20
# 最后合并后的特征矩阵的大小为： torch.Size([20, 1310])
# 最后合并后的距离矩阵的大小为： (20, 20)
# 最后合并后的标签的大小为： (20,)
# 3WJL_1_C_B
# 12
# 10
# all_target的大小为： 22
# tt的大小为： 22
# new_target的大小为： 22
# 最后合并后的特征矩阵的大小为： torch.Size([22, 1310])
# 最后合并后的距离矩阵的大小为： (22, 22)
# 最后合并后的标签的大小为： (22,)
# 3WN5_1_B_C
# 14
# 15
# all_target的大小为： 29
# tt的大小为： 29
# new_target的大小为： 29
# 最后合并后的特征矩阵的大小为： torch.Size([29, 1310])
# 最后合并后的距离矩阵的大小为： (29, 29)
# 最后合并后的标签的大小为： (29,)
# 3WN5_1_C_B
# 15
# 13
# all_target的大小为： 28
# tt的大小为： 28
# new_target的大小为： 28
# 最后合并后的特征矩阵的大小为： torch.Size([28, 1310])
# 最后合并后的距离矩阵的大小为： (28, 28)
# 最后合并后的标签的大小为： (28,)
# 3WO3_1_A_B
# 51
# 45
# all_target的大小为： 95
# tt的大小为： 95
# new_target的大小为： 95
# 最后合并后的特征矩阵的大小为： torch.Size([95, 1310])
# 最后合并后的距离矩阵的大小为： (95, 95)
# 最后合并后的标签的大小为： (95,)
# 3WO4_1_A_B
# 49
# 43
# all_target的大小为： 92
# tt的大小为： 92
# new_target的大小为： 92
# 最后合并后的特征矩阵的大小为： torch.Size([92, 1310])
# 最后合并后的距离矩阵的大小为： (92, 92)
# 最后合并后的标签的大小为： (92,)
# 3WO4_1_C_B
# 22
# 21
# all_target的大小为： 43
# tt的大小为： 43
# new_target的大小为： 43
# 最后合并后的特征矩阵的大小为： torch.Size([43, 1310])
# 最后合并后的距离矩阵的大小为： (43, 43)
# 最后合并后的标签的大小为： (43,)
# 3WSR_1_A_C
# 7
# 16
# all_target的大小为： 23
# tt的大小为： 23
# new_target的大小为： 23
# 最后合并后的特征矩阵的大小为： torch.Size([23, 1310])
# 最后合并后的距离矩阵的大小为： (23, 23)
# 最后合并后的标签的大小为： (23,)
# 3ZDX_1_A_B
# 40
# 48
# all_target的大小为： 88
# tt的大小为： 88
# new_target的大小为： 88
# 最后合并后的特征矩阵的大小为： torch.Size([88, 1310])
# 最后合并后的距离矩阵的大小为： (88, 88)
# 最后合并后的标签的大小为： (88,)
# 3ZDY_1_A_B
# 39
# 49
# all_target的大小为： 88
# tt的大小为： 88
# new_target的大小为： 88
# 最后合并后的特征矩阵的大小为： torch.Size([88, 1310])
# 最后合并后的距离矩阵的大小为： (88, 88)
# 最后合并后的标签的大小为： (88,)
# 3ZDZ_1_A_B
# 41
# 48
# all_target的大小为： 89
# tt的大小为： 89
# new_target的大小为： 89
# 最后合并后的特征矩阵的大小为： torch.Size([89, 1310])
# 最后合并后的距离矩阵的大小为： (89, 89)
# 最后合并后的标签的大小为： (89,)
# 3ZE0_1_A_B
# 40
# 47
# all_target的大小为： 87
# tt的大小为： 87
# new_target的大小为： 87
# 最后合并后的特征矩阵的大小为： torch.Size([87, 1310])
# 最后合并后的距离矩阵的大小为： (87, 87)
# 最后合并后的标签的大小为： (87,)
# 3ZE1_1_A_B
# 39
# 47
# all_target的大小为： 86
# tt的大小为： 86
# new_target的大小为： 86
# 最后合并后的特征矩阵的大小为： torch.Size([86, 1310])
# 最后合并后的距离矩阵的大小为： (86, 86)
# 最后合并后的标签的大小为： (86,)
# 3ZE2_1_A_B
# 40
# 49
# all_target的大小为： 89
# tt的大小为： 89
# new_target的大小为： 89
# 最后合并后的特征矩阵的大小为： torch.Size([89, 1310])
# 最后合并后的距离矩阵的大小为： (89, 89)
# 最后合并后的标签的大小为： (89,)
# 3ZS0_1_A_D
# 10
# 9
# all_target的大小为： 19
# tt的大小为： 19
# new_target的大小为： 19
# 最后合并后的特征矩阵的大小为： torch.Size([19, 1310])
# 最后合并后的距离矩阵的大小为： (19, 19)
# 最后合并后的标签的大小为： (19,)
# 3ZS0_1_B_C
# 10
# 9
# all_target的大小为： 19
# tt的大小为： 19
# new_target的大小为： 19
# 最后合并后的特征矩阵的大小为： torch.Size([19, 1310])
# 最后合并后的距离矩阵的大小为： (19, 19)
# 最后合并后的标签的大小为： (19,)
# 3ZTJ_1_G_A
# 6
# 11
# all_target的大小为： 17
# tt的大小为： 17
# new_target的大小为： 17
# 最后合并后的特征矩阵的大小为： torch.Size([17, 1310])
# 最后合并后的距离矩阵的大小为： (17, 17)
# 最后合并后的标签的大小为： (17,)
# 3ZTJ_1_I_C
# 2
# 4
# all_target的大小为： 6
# tt的大小为： 6
# new_target的大小为： 6
# 最后合并后的特征矩阵的大小为： torch.Size([6, 1310])
# 最后合并后的距离矩阵的大小为： (6, 6)
# 最后合并后的标签的大小为： (6,)
# 3ZTJ_1_K_E
# 2
# 4
# all_target的大小为： 6
# tt的大小为： 6
# new_target的大小为： 6
# 最后合并后的特征矩阵的大小为： torch.Size([6, 1310])
# 最后合并后的距离矩阵的大小为： (6, 6)
# 最后合并后的标签的大小为： (6,)
# 4AY5_1_A_I
# 10
# 34
# all_target的大小为： 44
# tt的大小为： 44
# new_target的大小为： 44
# 最后合并后的特征矩阵的大小为： torch.Size([44, 1310])
# 最后合并后的距离矩阵的大小为： (44, 44)
# 最后合并后的标签的大小为： (44,)
# 4AY9_1_E_D
# 53
# 57
# all_target的大小为： 110
# tt的大小为： 110
# new_target的大小为： 110
# 最后合并后的特征矩阵的大小为： torch.Size([110, 1310])
# 最后合并后的距离矩阵的大小为： (110, 110)
# 最后合并后的标签的大小为： (110,)
# 4AZ0_1_A_B
# 86
# 108
# all_target的大小为： 194
# tt的大小为： 194
# new_target的大小为： 194
# 最后合并后的特征矩阵的大小为： torch.Size([194, 1310])
# 最后合并后的距离矩阵的大小为： (194, 194)
# 最后合并后的标签的大小为： (194,)
# 4AZ0_1_B_A
# 107
# 86
# all_target的大小为： 193
# tt的大小为： 193
# new_target的大小为： 193
# 最后合并后的特征矩阵的大小为： torch.Size([193, 1310])
# 最后合并后的距离矩阵的大小为： (193, 193)
# 最后合并后的标签的大小为： (193,)
# 4AZ3_1_A_B
# 89
# 107
# all_target的大小为： 194
# tt的大小为： 194
# new_target的大小为： 194
# 最后合并后的特征矩阵的大小为： torch.Size([194, 1310])
# 最后合并后的距离矩阵的大小为： (194, 194)
# 最后合并后的标签的大小为： (194,)
# 4AZ3_1_B_A
# 106
# 89
# all_target的大小为： 193
# tt的大小为： 193
# new_target的大小为： 193
# 最后合并后的特征矩阵的大小为： torch.Size([193, 1310])
# 最后合并后的距离矩阵的大小为： (193, 193)
# 最后合并后的标签的大小为： (193,)
# 4BFI_1_B_A
# 27
# 22
# all_target的大小为： 49
# tt的大小为： 49
# new_target的大小为： 49
# 最后合并后的特征矩阵的大小为： torch.Size([49, 1310])
# 最后合并后的距离矩阵的大小为： (49, 49)
# 最后合并后的标签的大小为： (49,)
# 4BSA_1_A_B
# 71
# 67
# all_target的大小为： 138
# tt的大小为： 138
# new_target的大小为： 138
# 最后合并后的特征矩阵的大小为： torch.Size([138, 1310])
# 最后合并后的距离矩阵的大小为： (138, 138)
# 最后合并后的标签的大小为： (138,)
# 4BSB_1_A_B
# 71
# 69
# all_target的大小为： 140
# tt的大小为： 140
# new_target的大小为： 140
# 最后合并后的特征矩阵的大小为： torch.Size([140, 1310])
# 最后合并后的距离矩阵的大小为： (140, 140)
# 最后合并后的标签的大小为： (140,)
# 4BSC_1_A_B
# 73
# 68
# all_target的大小为： 141
# tt的大小为： 141
# new_target的大小为： 141
# 最后合并后的特征矩阵的大小为： torch.Size([141, 1310])
# 最后合并后的距离矩阵的大小为： (141, 141)
# 最后合并后的标签的大小为： (141,)
# 4BSD_1_A_B
# 71
# 63
# all_target的大小为： 134
# tt的大小为： 134
# new_target的大小为： 134
# 最后合并后的特征矩阵的大小为： torch.Size([134, 1310])
# 最后合并后的距离矩阵的大小为： (134, 134)
# 最后合并后的标签的大小为： (134,)
# 4BSE_1_A_B
# 73
# 67
# all_target的大小为： 140
# tt的大小为： 140
# new_target的大小为： 140
# 最后合并后的特征矩阵的大小为： torch.Size([140, 1310])
# 最后合并后的距离矩阵的大小为： (140, 140)
# 最后合并后的标签的大小为： (140,)
# 4BSF_1_A_B
# 70
# 67
# all_target的大小为： 137
# tt的大小为： 137
# new_target的大小为： 137
# 最后合并后的特征矩阵的大小为： torch.Size([137, 1310])
# 最后合并后的距离矩阵的大小为： (137, 137)
# 最后合并后的标签的大小为： (137,)
# 4BSG_1_A_B
# 74
# 66
# all_target的大小为： 140
# tt的大小为： 140
# new_target的大小为： 140
# 最后合并后的特征矩阵的大小为： torch.Size([140, 1310])
# 最后合并后的距离矩阵的大小为： (140, 140)
# 最后合并后的标签的大小为： (140,)
# 4BSH_1_A_B
# 74
# 67
# all_target的大小为： 141
# tt的大小为： 141
# new_target的大小为： 141
# 最后合并后的特征矩阵的大小为： torch.Size([141, 1310])
# 最后合并后的距离矩阵的大小为： (141, 141)
# 最后合并后的标签的大小为： (141,)
# 4BSI_1_A_B
# 71
# 68
# all_target的大小为： 139
# tt的大小为： 139
# new_target的大小为： 139
# 最后合并后的特征矩阵的大小为： torch.Size([139, 1310])
# 最后合并后的距离矩阵的大小为： (139, 139)
# 最后合并后的标签的大小为： (139,)
# 4BV4_1_L_R
# 21
# 14
# all_target的大小为： 35
# tt的大小为： 35
# new_target的大小为： 35
# 最后合并后的特征矩阵的大小为： torch.Size([35, 1310])
# 最后合并后的距离矩阵的大小为： (35, 35)
# 最后合并后的标签的大小为： (35,)
# 4BWC_1_B_A
# 69
# 75
# all_target的大小为： 144
# tt的大小为： 144
# new_target的大小为： 144
# 最后合并后的特征矩阵的大小为： torch.Size([144, 1310])
# 最后合并后的距离矩阵的大小为： (144, 144)
# 最后合并后的标签的大小为： (144,)
# 4CDC_1_I_G
# 8
# 9
# all_target的大小为： 17
# tt的大小为： 17
# new_target的大小为： 17
# 最后合并后的特征矩阵的大小为： torch.Size([17, 1310])
# 最后合并后的距离矩阵的大小为： (17, 17)
# 最后合并后的标签的大小为： (17,)
# 4CDE_1_F_D
# 8
# 9
# all_target的大小为： 17
# tt的大小为： 17
# new_target的大小为： 17
# 最后合并后的特征矩阵的大小为： torch.Size([17, 1310])
# 最后合并后的距离矩阵的大小为： (17, 17)
# 最后合并后的标签的大小为： (17,)
# 4D69_1_I_O
# 4
# 16
# all_target的大小为： 20
# tt的大小为： 20
# new_target的大小为： 20
# 最后合并后的特征矩阵的大小为： torch.Size([20, 1310])
# 最后合并后的距离矩阵的大小为： (20, 20)
# 最后合并后的标签的大小为： (20,)
# 4DAG_1_H_A
# 16
# 15
# all_target的大小为： 31
# tt的大小为： 31
# new_target的大小为： 31
# 最后合并后的特征矩阵的大小为： torch.Size([31, 1310])
# 最后合并后的距离矩阵的大小为： (31, 31)
# 最后合并后的标签的大小为： (31,)
# 4DEP_1_C_B
# 22
# 22
# all_target的大小为： 44
# tt的大小为： 44
# new_target的大小为： 44
# 最后合并后的特征矩阵的大小为： torch.Size([44, 1310])
# 最后合并后的距离矩阵的大小为： (44, 44)
# 最后合并后的标签的大小为： (44,)
# 4DKF_1_M_B
# 8
# 7
# all_target的大小为： 15
# tt的大小为： 15
# new_target的大小为： 15
# 最后合并后的特征矩阵的大小为： torch.Size([15, 1310])
# 最后合并后的距离矩阵的大小为： (15, 15)
# 最后合并后的标签的大小为： (15,)
# 4DL1_1_A_D
# 9
# 9
# all_target的大小为： 18
# tt的大小为： 18
# new_target的大小为： 18
# 最后合并后的特征矩阵的大小为： torch.Size([18, 1310])
# 最后合并后的距离矩阵的大小为： (18, 18)
# 最后合并后的标签的大小为： (18,)
# 4DL1_1_B_C
# 10
# 10
# all_target的大小为： 20
# tt的大小为： 20
# new_target的大小为： 20
# 最后合并后的特征矩阵的大小为： torch.Size([20, 1310])
# 最后合并后的距离矩阵的大小为： (20, 20)
# 最后合并后的标签的大小为： (20,)
# 4DQO_1_H_C
# 12
# 21
# all_target的大小为： 33
# tt的大小为： 33
# new_target的大小为： 33
# 最后合并后的特征矩阵的大小为： torch.Size([33, 1310])
# 最后合并后的距离矩阵的大小为： (33, 33)
# 最后合并后的标签的大小为： (33,)
# 4DVR_1_H_G
# 16
# 14
# all_target的大小为： 30
# tt的大小为： 30
# new_target的大小为： 30
# 最后合并后的特征矩阵的大小为： torch.Size([30, 1310])
# 最后合并后的距离矩阵的大小为： (30, 30)
# 最后合并后的标签的大小为： (30,)
# 4EB2_1_A_B
# 40
# 42
# all_target的大小为： 81
# tt的大小为： 81
# new_target的大小为： 81
# 最后合并后的特征矩阵的大小为： torch.Size([81, 1310])
# 最后合并后的距离矩阵的大小为： (81, 81)
# 最后合并后的标签的大小为： (81,)
# 4EI5_1_C_A
# 15
# 13
# all_target的大小为： 28
# tt的大小为： 28
# new_target的大小为： 28
# 最后合并后的特征矩阵的大小为： torch.Size([28, 1310])
# 最后合并后的距离矩阵的大小为： (28, 28)
# 最后合并后的标签的大小为： (28,)
# 4ELM_1_G_A
# 15
# 14
# all_target的大小为： 29
# tt的大小为： 29
# new_target的大小为： 29
# 最后合并后的特征矩阵的大小为： torch.Size([29, 1310])
# 最后合并后的距离矩阵的大小为： (29, 29)
# 最后合并后的标签的大小为： (29,)
# 4EXP_1_X_A
# 31
# 29
# all_target的大小为： 60
# tt的大小为： 60
# new_target的大小为： 60
# 最后合并后的特征矩阵的大小为： torch.Size([60, 1310])
# 最后合并后的距离矩阵的大小为： (60, 60)
# 最后合并后的标签的大小为： (60,)
# 4F4O_1_A_C
# 24
# 20
# all_target的大小为： 44
# tt的大小为： 44
# new_target的大小为： 44
# 最后合并后的特征矩阵的大小为： torch.Size([44, 1310])
# 最后合并后的距离矩阵的大小为： (44, 44)
# 最后合并后的标签的大小为： (44,)
# 4F4O_1_B_C
# 21
# 18
# all_target的大小为： 38
# tt的大小为： 38
# new_target的大小为： 38
# 最后合并后的特征矩阵的大小为： torch.Size([38, 1310])
# 最后合并后的距离矩阵的大小为： (38, 38)
# 最后合并后的标签的大小为： (38,)
# 4F4O_1_D_F
# 23
# 21
# all_target的大小为： 44
# tt的大小为： 44
# new_target的大小为： 44
# 最后合并后的特征矩阵的大小为： torch.Size([44, 1310])
# 最后合并后的距离矩阵的大小为： (44, 44)
# 最后合并后的标签的大小为： (44,)
# 4F4O_1_E_F
# 21
# 18
# all_target的大小为： 38
# tt的大小为： 38
# new_target的大小为： 38
# 最后合并后的特征矩阵的大小为： torch.Size([38, 1310])
# 最后合并后的距离矩阵的大小为： (38, 38)
# 最后合并后的标签的大小为： (38,)
# 4FQC_1_L_H
# 51
# 50
# all_target的大小为： 101
# tt的大小为： 101
# new_target的大小为： 101
# 最后合并后的特征矩阵的大小为： torch.Size([101, 1310])
# 最后合并后的距离矩阵的大小为： (101, 101)
# 最后合并后的标签的大小为： (101,)
# 4FQJ_1_H_A
# 19
# 17
# all_target的大小为： 36
# tt的大小为： 36
# new_target的大小为： 36
# 最后合并后的特征矩阵的大小为： torch.Size([36, 1310])
# 最后合并后的距离矩阵的大小为： (36, 36)
# 最后合并后的标签的大小为： (36,)
# 4FQX_1_B_A
# 65
# 54
# all_target的大小为： 119
# tt的大小为： 119
# new_target的大小为： 119
# 最后合并后的特征矩阵的大小为： torch.Size([119, 1310])
# 最后合并后的距离矩阵的大小为： (119, 119)
# 最后合并后的标签的大小为： (119,)
# 4G1E_1_A_B
# 122
# 123
# all_target的大小为： 245
# tt的大小为： 245
# new_target的大小为： 245
# 最后合并后的特征矩阵的大小为： torch.Size([245, 1310])
# 最后合并后的距离矩阵的大小为： (245, 245)
# 最后合并后的标签的大小为： (245,)
# 4G1E_1_B_A
# 120
# 141
# all_target的大小为： 261
# tt的大小为： 261
# new_target的大小为： 261
# 最后合并后的特征矩阵的大小为： torch.Size([261, 1310])
# 最后合并后的距离矩阵的大小为： (261, 261)
# 最后合并后的标签的大小为： (261,)
# 4G1M_1_A_B
# 80
# 87
# all_target的大小为： 167
# tt的大小为： 167
# new_target的大小为： 167
# ...
# new_target的大小为： 19
# 最后合并后的特征矩阵的大小为： torch.Size([19, 1310])
# 最后合并后的距离矩阵的大小为： (19, 19)
# 最后合并后的标签的大小为： (19,)
# 8TO7_1_J_B
# 4
# 3
# all_target的大小为： 7
# tt的大小为： 7
# new_target的大小为： 7
# 最后合并后的特征矩阵的大小为： torch.Size([7, 1310])
# 最后合并后的距离矩阵的大小为： (7, 7)
# 最后合并后的标签的大小为： (7,)
# 8TO7_1_K_A
# 5
# 3
# all_target的大小为： 8
# tt的大小为： 8
# new_target的大小为： 8
# 最后合并后的特征矩阵的大小为： torch.Size([8, 1310])
# 最后合并后的距离矩阵的大小为： (8, 8)
# 最后合并后的标签的大小为： (8,)
# 8TO7_1_L_C
# 5
# 4
# all_target的大小为： 9
# tt的大小为： 9
# new_target的大小为： 9
# 最后合并后的特征矩阵的大小为： torch.Size([9, 1310])
# 最后合并后的距离矩阵的大小为： (9, 9)
# 最后合并后的标签的大小为： (9,)
# 8TOP_1_H_A
# 7
# 13
# all_target的大小为： 20
# tt的大小为： 20
# new_target的大小为： 20
# 最后合并后的特征矩阵的大小为： torch.Size([20, 1310])
# 最后合并后的距离矩阵的大小为： (20, 20)
# 最后合并后的标签的大小为： (20,)
# 8TOP_1_J_C
# 6
# 13
# all_target的大小为： 19
# tt的大小为： 19
# new_target的大小为： 19
# 最后合并后的特征矩阵的大小为： torch.Size([19, 1310])
# 最后合并后的距离矩阵的大小为： (19, 19)
# 最后合并后的标签的大小为： (19,)
# 8TOP_1_M_E
# 6
# 13
# all_target的大小为： 19
# tt的大小为： 19
# new_target的大小为： 19
# 最后合并后的特征矩阵的大小为： torch.Size([19, 1310])
# 最后合并后的距离矩阵的大小为： (19, 19)
# 最后合并后的标签的大小为： (19,)
# 8TOP_1_U_O
# 5
# 12
# all_target的大小为： 17
# tt的大小为： 17
# new_target的大小为： 17
# 最后合并后的特征矩阵的大小为： torch.Size([17, 1310])
# 最后合并后的距离矩阵的大小为： (17, 17)
# 最后合并后的标签的大小为： (17,)
# 8TOP_1_W_Q
# 8
# 13
# all_target的大小为： 21
# tt的大小为： 21
# new_target的大小为： 21
# 最后合并后的特征矩阵的大小为： torch.Size([21, 1310])
# 最后合并后的距离矩阵的大小为： (21, 21)
# 最后合并后的标签的大小为： (21,)
# 8TOP_1_Y_S
# 6
# 12
# all_target的大小为： 18
# tt的大小为： 18
# new_target的大小为： 18
# 最后合并后的特征矩阵的大小为： torch.Size([18, 1310])
# 最后合并后的距离矩阵的大小为： (18, 18)
# 最后合并后的标签的大小为： (18,)
# 8TPA_1_D_C
# 18
# 15
# all_target的大小为： 33
# tt的大小为： 33
# new_target的大小为： 33
# 最后合并后的特征矩阵的大小为： torch.Size([33, 1310])
# 最后合并后的距离矩阵的大小为： (33, 33)
# 最后合并后的标签的大小为： (33,)
# 8TPA_1_H_A
# 18
# 15
# all_target的大小为： 33
# tt的大小为： 33
# new_target的大小为： 33
# 最后合并后的特征矩阵的大小为： torch.Size([33, 1310])
# 最后合并后的距离矩阵的大小为： (33, 33)
# 最后合并后的标签的大小为： (33,)
# 8TPA_1_I_G
# 18
# 15
# all_target的大小为： 33
# tt的大小为： 33
# new_target的大小为： 33
# 最后合并后的特征矩阵的大小为： torch.Size([33, 1310])
# 最后合并后的距离矩阵的大小为： (33, 33)
# 最后合并后的标签的大小为： (33,)
# 8TRL_1_B_A
# 63
# 54
# all_target的大小为： 117
# tt的大小为： 117
# new_target的大小为： 117
# 最后合并后的特征矩阵的大小为： torch.Size([117, 1310])
# 最后合并后的距离矩阵的大小为： (117, 117)
# 最后合并后的标签的大小为： (117,)
# 8TRQ_1_B_A
# 63
# 54
# all_target的大小为： 117
# tt的大小为： 117
# new_target的大小为： 117
# 最后合并后的特征矩阵的大小为： torch.Size([117, 1310])
# 最后合并后的距离矩阵的大小为： (117, 117)
# 最后合并后的标签的大小为： (117,)
# 8TRR_1_B_A
# 63
# 53
# all_target的大小为： 116
# tt的大小为： 116
# new_target的大小为： 116
# 最后合并后的特征矩阵的大小为： torch.Size([116, 1310])
# 最后合并后的距离矩阵的大小为： (116, 116)
# 最后合并后的标签的大小为： (116,)
# 8TTW_1_C_A
# 22
# 42
# all_target的大小为： 64
# tt的大小为： 64
# new_target的大小为： 64
# 最后合并后的特征矩阵的大小为： torch.Size([64, 1310])
# 最后合并后的距离矩阵的大小为： (64, 64)
# 最后合并后的标签的大小为： (64,)
# 8TTW_1_D_B
# 10
# 13
# all_target的大小为： 23
# tt的大小为： 23
# new_target的大小为： 23
# 最后合并后的特征矩阵的大小为： torch.Size([23, 1310])
# 最后合并后的距离矩阵的大小为： (23, 23)
# 最后合并后的标签的大小为： (23,)
# 8TTW_1_G_E
# 22
# 42
# all_target的大小为： 64
# tt的大小为： 64
# new_target的大小为： 64
# 最后合并后的特征矩阵的大小为： torch.Size([64, 1310])
# 最后合并后的距离矩阵的大小为： (64, 64)
# 最后合并后的标签的大小为： (64,)
# 8TTW_1_H_F
# 10
# 13
# all_target的大小为： 23
# tt的大小为： 23
# new_target的大小为： 23
# 最后合并后的特征矩阵的大小为： torch.Size([23, 1310])
# 最后合并后的距离矩阵的大小为： (23, 23)
# 最后合并后的标签的大小为： (23,)
# 8TTW_1_K_I
# 22
# 42
# all_target的大小为： 64
# tt的大小为： 64
# new_target的大小为： 64
# 最后合并后的特征矩阵的大小为： torch.Size([64, 1310])
# 最后合并后的距离矩阵的大小为： (64, 64)
# 最后合并后的标签的大小为： (64,)
# 8TTW_1_L_J
# 10
# 13
# all_target的大小为： 23
# tt的大小为： 23
# new_target的大小为： 23
# 最后合并后的特征矩阵的大小为： torch.Size([23, 1310])
# 最后合并后的距离矩阵的大小为： (23, 23)
# 最后合并后的标签的大小为： (23,)
# 8TTW_1_M_A
# 12
# 10
# all_target的大小为： 22
# tt的大小为： 22
# new_target的大小为： 22
# 最后合并后的特征矩阵的大小为： torch.Size([22, 1310])
# 最后合并后的距离矩阵的大小为： (22, 22)
# 最后合并后的标签的大小为： (22,)
# 8TTW_1_N_A
# 11
# 16
# all_target的大小为： 27
# tt的大小为： 27
# new_target的大小为： 27
# 最后合并后的特征矩阵的大小为： torch.Size([27, 1310])
# 最后合并后的距离矩阵的大小为： (27, 27)
# 最后合并后的标签的大小为： (27,)
# 8TTW_1_O_E
# 12
# 10
# all_target的大小为： 22
# tt的大小为： 22
# new_target的大小为： 22
# 最后合并后的特征矩阵的大小为： torch.Size([22, 1310])
# 最后合并后的距离矩阵的大小为： (22, 22)
# 最后合并后的标签的大小为： (22,)
# 8TTW_1_P_E
# 10
# 15
# all_target的大小为： 25
# tt的大小为： 25
# new_target的大小为： 25
# 最后合并后的特征矩阵的大小为： torch.Size([25, 1310])
# 最后合并后的距离矩阵的大小为： (25, 25)
# 最后合并后的标签的大小为： (25,)
# 8TTW_1_Q_I
# 12
# 10
# all_target的大小为： 22
# tt的大小为： 22
# new_target的大小为： 22
# 最后合并后的特征矩阵的大小为： torch.Size([22, 1310])
# 最后合并后的距离矩阵的大小为： (22, 22)
# 最后合并后的标签的大小为： (22,)
# 8TTW_1_R_I
# 10
# 15
# all_target的大小为： 25
# tt的大小为： 25
# new_target的大小为： 25
# 最后合并后的特征矩阵的大小为： torch.Size([25, 1310])
# 最后合并后的距离矩阵的大小为： (25, 25)
# 最后合并后的标签的大小为： (25,)
# 8TXP_1_H_A
# 13
# 11
# all_target的大小为： 24
# tt的大小为： 24
# new_target的大小为： 24
# 最后合并后的特征矩阵的大小为： torch.Size([24, 1310])
# 最后合并后的距离矩阵的大小为： (24, 24)
# 最后合并后的标签的大小为： (24,)
# 8TXT_1_G_A
# 4
# 4
# all_target的大小为： 8
# tt的大小为： 8
# new_target的大小为： 8
# 最后合并后的特征矩阵的大小为： torch.Size([8, 1310])
# 最后合并后的距离矩阵的大小为： (8, 8)
# 最后合并后的标签的大小为： (8,)
# 8TXT_1_H_C
# 3
# 4
# all_target的大小为： 7
# tt的大小为： 7
# new_target的大小为： 7
# 最后合并后的特征矩阵的大小为： torch.Size([7, 1310])
# 最后合并后的距离矩阵的大小为： (7, 7)
# 最后合并后的标签的大小为： (7,)
# 8TXT_1_I_D
# 5
# 8
# all_target的大小为： 13
# tt的大小为： 13
# new_target的大小为： 13
# 最后合并后的特征矩阵的大小为： torch.Size([13, 1310])
# 最后合并后的距离矩阵的大小为： (13, 13)
# 最后合并后的标签的大小为： (13,)
# 8TXT_1_J_E
# 4
# 4
# all_target的大小为： 8
# tt的大小为： 8
# new_target的大小为： 8
# 最后合并后的特征矩阵的大小为： torch.Size([8, 1310])
# 最后合并后的距离矩阵的大小为： (8, 8)
# 最后合并后的标签的大小为： (8,)
# 8TXT_1_K_B
# 6
# 7
# all_target的大小为： 13
# tt的大小为： 13
# new_target的大小为： 13
# 最后合并后的特征矩阵的大小为： torch.Size([13, 1310])
# 最后合并后的距离矩阵的大小为： (13, 13)
# 最后合并后的标签的大小为： (13,)
# 8TXT_1_L_F
# 5
# 7
# all_target的大小为： 12
# tt的大小为： 12
# new_target的大小为： 12
# 最后合并后的特征矩阵的大小为： torch.Size([12, 1310])
# 最后合并后的距离矩阵的大小为： (12, 12)
# 最后合并后的标签的大小为： (12,)
# 8TY7_1_L_B
# 5
# 4
# all_target的大小为： 9
# tt的大小为： 9
# new_target的大小为： 9
# 最后合并后的特征矩阵的大小为： torch.Size([9, 1310])
# 最后合并后的距离矩阵的大小为： (9, 9)
# 最后合并后的标签的大小为： (9,)
# 8TZO_1_B_A
# 46
# 75
# all_target的大小为： 121
# tt的大小为： 121
# new_target的大小为： 121
# 最后合并后的特征矩阵的大小为： torch.Size([121, 1310])
# 最后合并后的距离矩阵的大小为： (121, 121)
# 最后合并后的标签的大小为： (121,)
# 8TZR_1_B_A
# 52
# 84
# all_target的大小为： 136
# tt的大小为： 136
# new_target的大小为： 136
# 最后合并后的特征矩阵的大小为： torch.Size([136, 1310])
# 最后合并后的距离矩阵的大小为： (136, 136)
# 最后合并后的标签的大小为： (136,)
# 8U44_1_S_G
# 10
# 15
# all_target的大小为： 25
# tt的大小为： 25
# new_target的大小为： 25
# 最后合并后的特征矩阵的大小为： torch.Size([25, 1310])
# 最后合并后的距离矩阵的大小为： (25, 25)
# 最后合并后的标签的大小为： (25,)
# 8U44_1_U_H
# 10
# 15
# all_target的大小为： 25
# tt的大小为： 25
# new_target的大小为： 25
# 最后合并后的特征矩阵的大小为： torch.Size([25, 1310])
# 最后合并后的距离矩阵的大小为： (25, 25)
# 最后合并后的标签的大小为： (25,)
# 8U44_1_V_A
# 10
# 15
# all_target的大小为： 25
# tt的大小为： 25
# new_target的大小为： 25
# 最后合并后的特征矩阵的大小为： torch.Size([25, 1310])
# 最后合并后的距离矩阵的大小为： (25, 25)
# 最后合并后的标签的大小为： (25,)
# 8UA8_1_A_B
# 79
# 79
# all_target的大小为： 158
# tt的大小为： 158
# new_target的大小为： 158
# 最后合并后的特征矩阵的大小为： torch.Size([158, 1310])
# 最后合并后的距离矩阵的大小为： (158, 158)
# 最后合并后的标签的大小为： (158,)
# 8UA8_1_E_F
# 82
# 83
# all_target的大小为： 165
# tt的大小为： 165
# new_target的大小为： 165
# 最后合并后的特征矩阵的大小为： torch.Size([165, 1310])
# 最后合并后的距离矩阵的大小为： (165, 165)
# 最后合并后的标签的大小为： (165,)
# 8UA8_1_I_J
# 84
# 82
# all_target的大小为： 166
# tt的大小为： 166
# new_target的大小为： 166
# 最后合并后的特征矩阵的大小为： torch.Size([166, 1310])
# 最后合并后的距离矩阵的大小为： (166, 166)
# 最后合并后的标签的大小为： (166,)
# 8UA8_1_M_N
# 80
# 84
# all_target的大小为： 164
# tt的大小为： 164
# new_target的大小为： 164
# 最后合并后的特征矩阵的大小为： torch.Size([164, 1310])
# 最后合并后的距离矩阵的大小为： (164, 164)
# 最后合并后的标签的大小为： (164,)
# 8UG9_1_M_A
# 25
# 22
# all_target的大小为： 47
# tt的大小为： 47
# new_target的大小为： 47
# 最后合并后的特征矩阵的大小为： torch.Size([47, 1310])
# 最后合并后的距离矩阵的大小为： (47, 47)
# 最后合并后的标签的大小为： (47,)
# 8UG9_1_N_B
# 26
# 20
# all_target的大小为： 46
# tt的大小为： 46
# new_target的大小为： 46
# 最后合并后的特征矩阵的大小为： torch.Size([46, 1310])
# 最后合并后的距离矩阵的大小为： (46, 46)
# 最后合并后的标签的大小为： (46,)
# 8UG9_1_O_C
# 26
# 21
# all_target的大小为： 47
# tt的大小为： 47
# new_target的大小为： 47
# 最后合并后的特征矩阵的大小为： torch.Size([47, 1310])
# 最后合并后的距离矩阵的大小为： (47, 47)
# 最后合并后的标签的大小为： (47,)
# 8UH2_1_A_B
# 105
# 114
# all_target的大小为： 219
# tt的大小为： 219
# new_target的大小为： 219
# 最后合并后的特征矩阵的大小为： torch.Size([219, 1310])
# 最后合并后的距离矩阵的大小为： (219, 219)
# 最后合并后的标签的大小为： (219,)
# 8UH2_1_G_H
# 106
# 113
# all_target的大小为： 219
# tt的大小为： 219
# new_target的大小为： 219
# 最后合并后的特征矩阵的大小为： torch.Size([219, 1310])
# 最后合并后的距离矩阵的大小为： (219, 219)
# 最后合并后的标签的大小为： (219,)
# 8UIN_1_A_B
# 107
# 115
# all_target的大小为： 222
# tt的大小为： 222
# new_target的大小为： 222
# 最后合并后的特征矩阵的大小为： torch.Size([222, 1310])
# 最后合并后的距离矩阵的大小为： (222, 222)
# 最后合并后的标签的大小为： (222,)
# 8UIN_1_G_H
# 109
# 110
# all_target的大小为： 219
# tt的大小为： 219
# new_target的大小为： 219
# 最后合并后的特征矩阵的大小为： torch.Size([219, 1310])
# 最后合并后的距离矩阵的大小为： (219, 219)
# 最后合并后的标签的大小为： (219,)
# 8UT3_1_F_C
# 17
# 12
# all_target的大小为： 29
# tt的大小为： 29
# new_target的大小为： 29
# 最后合并后的特征矩阵的大小为： torch.Size([29, 1310])
# 最后合并后的距离矩阵的大小为： (29, 29)
# 最后合并后的标签的大小为： (29,)
# 8UT4_1_H_A
# 2
# 3
# all_target的大小为： 5
# tt的大小为： 5
# new_target的大小为： 5
# 最后合并后的特征矩阵的大小为： torch.Size([5, 1310])
# 最后合并后的距离矩阵的大小为： (5, 5)
# 最后合并后的标签的大小为： (5,)
# 8UT5_1_H_A
# 2
# 2
# all_target的大小为： 4
# tt的大小为： 4
# new_target的大小为： 4
# 最后合并后的特征矩阵的大小为： torch.Size([4, 1310])
# 最后合并后的距离矩阵的大小为： (4, 4)
# 最后合并后的标签的大小为： (4,)
# 8VCX_1_B_A
# 68
# 57
# all_target的大小为： 125
# tt的大小为： 125
# new_target的大小为： 125
# 最后合并后的特征矩阵的大小为： torch.Size([125, 1310])
# 最后合并后的距离矩阵的大小为： (125, 125)
# 最后合并后的标签的大小为： (125,)
# 8VDU_1_H_A
# 13
# 12
# all_target的大小为： 25
# tt的大小为： 25
# new_target的大小为： 25
# 最后合并后的特征矩阵的大小为： torch.Size([25, 1310])
# 最后合并后的距离矩阵的大小为： (25, 25)
# 最后合并后的标签的大小为： (25,)
# 8VDU_1_K_A
# 6
# 6
# all_target的大小为： 12
# tt的大小为： 12
# new_target的大小为： 12
# 最后合并后的特征矩阵的大小为： torch.Size([12, 1310])
# 最后合并后的距离矩阵的大小为： (12, 12)
# 最后合并后的标签的大小为： (12,)
# 8VQC_1_H_A
# 18
# 22
# all_target的大小为： 40
# tt的大小为： 40
# new_target的大小为： 40
# 最后合并后的特征矩阵的大小为： torch.Size([40, 1310])
# 最后合并后的距离矩阵的大小为： (40, 40)
# 最后合并后的标签的大小为： (40,)
# 8VYG_1_A_R
# 16
# 14
# all_target的大小为： 30
# tt的大小为： 30
# new_target的大小为： 30
# 最后合并后的特征矩阵的大小为： torch.Size([30, 1310])
# 最后合并后的距离矩阵的大小为： (30, 30)
# 最后合并后的标签的大小为： (30,)
# 8VYG_1_B_R
# 5
# 5
# all_target的大小为： 10
# tt的大小为： 10
# new_target的大小为： 10
# 最后合并后的特征矩阵的大小为： torch.Size([10, 1310])
# 最后合并后的距离矩阵的大小为： (10, 10)
# 最后合并后的标签的大小为： (10,)
# 8W0V_1_H_C
# 26
# 25
# all_target的大小为： 51
# tt的大小为： 51
# new_target的大小为： 51
# 最后合并后的特征矩阵的大小为： torch.Size([51, 1310])
# 最后合并后的距离矩阵的大小为： (51, 51)
# 最后合并后的标签的大小为： (51,)
# 8W0V_1_L_C
# 2
# 6
# all_target的大小为： 8
# tt的大小为： 8
# new_target的大小为： 8
# 最后合并后的特征矩阵的大小为： torch.Size([8, 1310])
# 最后合并后的距离矩阵的大小为： (8, 8)
# 最后合并后的标签的大小为： (8,)
# 8W0W_1_H_C
# 23
# 24
# all_target的大小为： 47
# tt的大小为： 47
# new_target的大小为： 47
# 最后合并后的特征矩阵的大小为： torch.Size([47, 1310])
# 最后合并后的距离矩阵的大小为： (47, 47)
# 最后合并后的标签的大小为： (47,)
# 8W0W_1_L_C
# 3
# 8
# all_target的大小为： 11
# tt的大小为： 11
# new_target的大小为： 11
# 最后合并后的特征矩阵的大小为： torch.Size([11, 1310])
# 最后合并后的距离矩阵的大小为： (11, 11)
# 最后合并后的标签的大小为： (11,)
# 8W0X_1_H_C
# 27
# 27
# all_target的大小为： 54
# tt的大小为： 54
# new_target的大小为： 54
# 最后合并后的特征矩阵的大小为： torch.Size([54, 1310])
# 最后合并后的距离矩阵的大小为： (54, 54)
# 最后合并后的标签的大小为： (54,)
# 8W0Y_1_A_D
# 21
# 24
# all_target的大小为： 45
# tt的大小为： 45
# new_target的大小为： 45
# 最后合并后的特征矩阵的大小为： torch.Size([45, 1310])
# 最后合并后的距离矩阵的大小为： (45, 45)
# 最后合并后的标签的大小为： (45,)
# 8WE4_1_H_A
# 3
# 3
# all_target的大小为： 6
# tt的大小为： 6
# new_target的大小为： 6
# 最后合并后的特征矩阵的大小为： torch.Size([6, 1310])
# 最后合并后的距离矩阵的大小为： (6, 6)
# 最后合并后的标签的大小为： (6,)
# 8WEJ_1_H_B
# 17
# 17
# all_target的大小为： 34
# tt的大小为： 34
# new_target的大小为： 34
# 最后合并后的特征矩阵的大小为： torch.Size([34, 1310])
# 最后合并后的距离矩阵的大小为： (34, 34)
# 最后合并后的标签的大小为： (34,)
# 8WEJ_1_L_B
# 9
# 11
# all_target的大小为： 20
# tt的大小为： 20
# new_target的大小为： 20
# 最后合并后的特征矩阵的大小为： torch.Size([20, 1310])
# 最后合并后的距离矩阵的大小为： (20, 20)
# 最后合并后的标签的大小为： (20,)
# 8WKU_1_B_A
# 21
# 29
# all_target的大小为： 50
# tt的大小为： 50
# new_target的大小为： 50
# 最后合并后的特征矩阵的大小为： torch.Size([50, 1310])
# 最后合并后的距离矩阵的大小为： (50, 50)
# 最后合并后的标签的大小为： (50,)
# 8WP8_1_B_A
# 23
# 25
# all_target的大小为： 48
# tt的大小为： 48
# new_target的大小为： 48
# 最后合并后的特征矩阵的大小为： torch.Size([48, 1310])
# 最后合并后的距离矩阵的大小为： (48, 48)
# 最后合并后的标签的大小为： (48,)
# 8X2L_1_H_B
# 16
# 17
# all_target的大小为： 33
# tt的大小为： 33
# new_target的大小为： 33
# 最后合并后的特征矩阵的大小为： torch.Size([33, 1310])
# 最后合并后的距离矩阵的大小为： (33, 33)
# 最后合并后的标签的大小为： (33,)
# 8X2L_1_L_B
# 10
# 11
# all_target的大小为： 21
# tt的大小为： 21
# new_target的大小为： 21
# 最后合并后的特征矩阵的大小为： torch.Size([21, 1310])
# 最后合并后的距离矩阵的大小为： (21, 21)
# 最后合并后的标签的大小为： (21,)
# 8XI6_1_D_A
# 10
# 17
# all_target的大小为： 27
# tt的大小为： 27
# new_target的大小为： 27
# 最后合并后的特征矩阵的大小为： torch.Size([27, 1310])
# 最后合并后的距离矩阵的大小为： (27, 27)
# 最后合并后的标签的大小为： (27,)
# 8XI6_1_F_B
# 10
# 17
# all_target的大小为： 27
# tt的大小为： 27
# new_target的大小为： 27
# 最后合并后的特征矩阵的大小为： torch.Size([27, 1310])
# 最后合并后的距离矩阵的大小为： (27, 27)
# 最后合并后的标签的大小为： (27,)
# 8XI6_1_H_C
# 10
# 17
# all_target的大小为： 27
# tt的大小为： 27
# new_target的大小为： 27
# 最后合并后的特征矩阵的大小为： torch.Size([27, 1310])
# 最后合并后的距离矩阵的大小为： (27, 27)
# 最后合并后的标签的大小为： (27,)
# 8XLN_1_A_D
# 18
# 23
# all_target的大小为： 41
# tt的大小为： 41
# new_target的大小为： 41
# 最后合并后的特征矩阵的大小为： torch.Size([41, 1310])
# 最后合并后的距离矩阵的大小为： (41, 41)
# 最后合并后的标签的大小为： (41,)
# 8XN2_1_B_A
# 22
# 24
# all_target的大小为： 45
# tt的大小为： 45
# new_target的大小为： 45
# 最后合并后的特征矩阵的大小为： torch.Size([45, 1310])
# 最后合并后的距离矩阵的大小为： (45, 45)
# 最后合并后的标签的大小为： (45,)
# 8Y18_1_B_A
# 20
# 19
# all_target的大小为： 39
# tt的大小为： 39
# new_target的大小为： 39
# 最后合并后的特征矩阵的大小为： torch.Size([39, 1310])
# 最后合并后的距离矩阵的大小为： (39, 39)
# 最后合并后的标签的大小为： (39,)
# 8Y4C_1_D_B
# 15
# 19
# all_target的大小为： 34
# tt的大小为： 34
# new_target的大小为： 34
# 最后合并后的特征矩阵的大小为： torch.Size([34, 1310])
# 最后合并后的距离矩阵的大小为： (34, 34)
# 最后合并后的标签的大小为： (34,)
# 8Y4C_1_E_C
# 16
# 19
# all_target的大小为： 35
# tt的大小为： 35
# new_target的大小为： 35
# 最后合并后的特征矩阵的大小为： torch.Size([35, 1310])
# 最后合并后的距离矩阵的大小为： (35, 35)
# 最后合并后的标签的大小为： (35,)
# 8Y4C_1_F_B
# 27
# 30
# all_target的大小为： 57
# tt的大小为： 57
# new_target的大小为： 57
# 最后合并后的特征矩阵的大小为： torch.Size([57, 1310])
# 最后合并后的距离矩阵的大小为： (57, 57)
# 最后合并后的标签的大小为： (57,)
# 8Y4C_1_G_C
# 27
# 30
# all_target的大小为： 57
# tt的大小为： 57
# new_target的大小为： 57
# 最后合并后的特征矩阵的大小为： torch.Size([57, 1310])
# 最后合并后的距离矩阵的大小为： (57, 57)
# 最后合并后的标签的大小为： (57,)
# 8Y4C_1_H_A
# 16
# 18
# all_target的大小为： 34
# tt的大小为： 34
# new_target的大小为： 34
# 最后合并后的特征矩阵的大小为： torch.Size([34, 1310])
# 最后合并后的距离矩阵的大小为： (34, 34)
# 最后合并后的标签的大小为： (34,)
# 8Y4C_1_L_A
# 27
# 30
# all_target的大小为： 57
# tt的大小为： 57
# new_target的大小为： 57
# 最后合并后的特征矩阵的大小为： torch.Size([57, 1310])
# 最后合并后的距离矩阵的大小为： (57, 57)
# 最后合并后的标签的大小为： (57,)
# 8Y6A_1_B_A
# 28
# 25
# all_target的大小为： 52
# tt的大小为： 52
# new_target的大小为： 52
# 最后合并后的特征矩阵的大小为： torch.Size([52, 1310])
# 最后合并后的距离矩阵的大小为： (52, 52)
# 最后合并后的标签的大小为： (52,)
# 8Y6A_1_C_B
# 17
# 14
# all_target的大小为： 31
# tt的大小为： 31
# new_target的大小为： 31
# 最后合并后的特征矩阵的大小为： torch.Size([31, 1310])
# 最后合并后的距离矩阵的大小为： (31, 31)
# 最后合并后的标签的大小为： (31,)
# 8Y6A_1_D_B
# 6
# 6
# all_target的大小为： 12
# tt的大小为： 12
# new_target的大小为： 12
# 最后合并后的特征矩阵的大小为： torch.Size([12, 1310])
# 最后合并后的距离矩阵的大小为： (12, 12)
# 最后合并后的标签的大小为： (12,)
# 8Y7Y_1_B_A
# 23
# 20
# all_target的大小为： 43
# tt的大小为： 43
# new_target的大小为： 43
# 最后合并后的特征矩阵的大小为： torch.Size([43, 1310])
# 最后合并后的距离矩阵的大小为： (43, 43)
# 最后合并后的标签的大小为： (43,)
# 8Y81_1_A_F
# 13
# 12
# all_target的大小为： 25
# tt的大小为： 25
# new_target的大小为： 25
# 最后合并后的特征矩阵的大小为： torch.Size([25, 1310])
# 最后合并后的距离矩阵的大小为： (25, 25)
# 最后合并后的标签的大小为： (25,)
# 8Y8B_1_B_A
# 23
# 20
# all_target的大小为： 43
# tt的大小为： 43
# new_target的大小为： 43
# 最后合并后的特征矩阵的大小为： torch.Size([43, 1310])
# 最后合并后的距离矩阵的大小为： (43, 43)
# 最后合并后的标签的大小为： (43,)
# 8Y8J_1_B_A
# 24
# 20
# all_target的大小为： 44
# tt的大小为： 44
# new_target的大小为： 44
# 最后合并后的特征矩阵的大小为： torch.Size([44, 1310])
# 最后合并后的距离矩阵的大小为： (44, 44)
# 最后合并后的标签的大小为： (44,)
# 8YI7_1_C_B
# 7
# 5
# all_target的大小为： 12
# tt的大小为： 12
# new_target的大小为： 12
# 最后合并后的特征矩阵的大小为： torch.Size([12, 1310])
# 最后合并后的距离矩阵的大小为： (12, 12)
# 最后合并后的标签的大小为： (12,)
# 8Z0T_1_A_E
# 13
# 12
# all_target的大小为： 25
# tt的大小为： 25
# new_target的大小为： 25
# 最后合并后的特征矩阵的大小为： torch.Size([25, 1310])
# 最后合并后的距离矩阵的大小为： (25, 25)
# 最后合并后的标签的大小为： (25,)
# 8ZGS_1_A_F
# 11
# 11
# all_target的大小为： 22
# tt的大小为： 22
# new_target的大小为： 22
# 最后合并后的特征矩阵的大小为： torch.Size([22, 1310])
# 最后合并后的距离矩阵的大小为： (22, 22)
# 最后合并后的标签的大小为： (22,)
# 8ZGT_1_A_F
# 11
# 10
# all_target的大小为： 21
# tt的大小为： 21
# new_target的大小为： 21
# 最后合并后的特征矩阵的大小为： torch.Size([21, 1310])
# 最后合并后的距离矩阵的大小为： (21, 21)
# 最后合并后的标签的大小为： (21,)
# 8ZHE_1_F_C
# 11
# 12
# all_target的大小为： 23
# tt的大小为： 23
# new_target的大小为： 23
# 最后合并后的特征矩阵的大小为： torch.Size([23, 1310])
# 最后合并后的距离矩阵的大小为： (23, 23)
# 最后合并后的标签的大小为： (23,)
# 8ZHE_1_H_A
# 12
# 13
# all_target的大小为： 25
# tt的大小为： 25
# new_target的大小为： 25
# 最后合并后的特征矩阵的大小为： torch.Size([25, 1310])
# 最后合并后的距离矩阵的大小为： (25, 25)
# 最后合并后的标签的大小为： (25,)
# 8ZHE_1_J_B
# 12
# 12
# all_target的大小为： 24
# tt的大小为： 24
# new_target的大小为： 24
# 最后合并后的特征矩阵的大小为： torch.Size([24, 1310])
# 最后合并后的距离矩阵的大小为： (24, 24)
# 最后合并后的标签的大小为： (24,)
# 8ZHG_1_H_C
# 13
# 12
# all_target的大小为： 25
# tt的大小为： 25
# new_target的大小为： 25
# 最后合并后的特征矩阵的大小为： torch.Size([25, 1310])
# 最后合并后的距离矩阵的大小为： (25, 25)
# 最后合并后的标签的大小为： (25,)
# 9AT8_1_F_E
# 20
# 37
# all_target的大小为： 57
# tt的大小为： 57
# new_target的大小为： 57
# 最后合并后的特征矩阵的大小为： torch.Size([57, 1310])
# 最后合并后的距离矩阵的大小为： (57, 57)
# 最后合并后的标签的大小为： (57,)
# 9B7B_1_B_A
# 77
# 74
# all_target的大小为： 151
# tt的大小为： 151
# new_target的大小为： 151
# 最后合并后的特征矩阵的大小为： torch.Size([151, 1310])
# 最后合并后的距离矩阵的大小为： (151, 151)
# 最后合并后的标签的大小为： (151,)
# 9B8O_1_p_P
# 30
# 17
# all_target的大小为： 47
# tt的大小为： 47
# new_target的大小为： 47
# 最后合并后的特征矩阵的大小为： torch.Size([47, 1310])
# 最后合并后的距离矩阵的大小为： (47, 47)
# 最后合并后的标签的大小为： (47,)
# 9BRZ_1_b_c
# 24
# 21
# all_target的大小为： 45
# tt的大小为： 45
# new_target的大小为： 45
# 最后合并后的特征矩阵的大小为： torch.Size([45, 1310])
# 最后合并后的距离矩阵的大小为： (45, 45)
# 最后合并后的标签的大小为： (45,)
# 9CKV_1_C_A
# 15
# 10
# all_target的大小为： 25
# tt的大小为： 25
# new_target的大小为： 25
# 最后合并后的特征矩阵的大小为： torch.Size([25, 1310])
# 最后合并后的距离矩阵的大小为： (25, 25)
# 最后合并后的标签的大小为： (25,)
# 9F1I_1_H_P
# 5
# 15
# all_target的大小为： 20
# tt的大小为： 20
# new_target的大小为： 20
# 最后合并后的特征矩阵的大小为： torch.Size([20, 1310])
# 最后合并后的距离矩阵的大小为： (20, 20)
# 最后合并后的标签的大小为： (20,)
